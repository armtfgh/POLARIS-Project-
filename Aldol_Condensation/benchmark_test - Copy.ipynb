# %%
#!/usr/bin/env python
# benchmark_aldol_priors_llm.py
"""
Closed-loop benchmark on Aldol dataset with:
- Real LLM-shaped priors via OpenAI API (good and intentionally-bad prompts)
- NoPrior / Heuristic / RandomPrior baselines
- Controlled initial seeding: good (top-yld), bad (bottom-yld), random

Usage:
  python benchmark_aldol_priors_llm.py \
    --oracle aldol_oracle_out/oracle.pkl \
    --data_csv "Aldol Condensation.csv" \
    --out_dir aldol_bench_llm \
    --priors no_prior,heuristic,llm_good,llm_bad,random_prior \
    --init_modes good,bad,random \
    --n_reps 5 --iters 20 --n_init 6 --cand_pool 600 \
    --llm_model gpt-4o-mini

Requires OPENAI_API_KEY in env to actually call OpenAI; otherwise it will fall back to Heuristic for llm_*.
"""
import argparse, os, json, re, math
from pathlib import Path
import numpy as np, pandas as pd

from scipy.stats import norm
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel

try:
    import joblib
except Exception:
    joblib = None

import sys

import language_shaped_prior_llm as lsp

# ---------------------- utilities ----------------------

def load_oracle(p):
    if joblib is None:
        raise ImportError("joblib required: pip install joblib")
    return joblib.load(p)

def derive_schema(csv_path: str):
    df = pd.read_csv(csv_path).dropna()
    feats = [c for c in df.columns if c != "yld"]
    bounds = {c:(float(df[c].min()), float(df[c].max())) for c in feats}
    roles = {"temp":"temperature", "time":"time", "moleq2":"equivalents", "moleq3":"equivalents"}
    cont = [lsp.ContinuousVar(c, bounds[c][0], bounds[c][1], role=roles.get(c,"")) for c in feats]
    return lsp.Schema(continuous=cont, categorical=[]), df

def sample_candidates(n, rng, schema: lsp.Schema):
    rows = []
    for _ in range(n):
        r = {}
        for v in schema.continuous:
            r[v.name] = rng.uniform(v.low, v.high)
        rows.append(r)
    return pd.DataFrame(rows)

def expected_improvement(mu, sigma, y_best, xi=0.01):
    sigma = np.maximum(sigma, 1e-9)
    z = (mu - y_best - xi) / sigma
    return (mu - y_best - xi) * norm.cdf(z) + sigma * norm.pdf(z)

def area_under_curve(curve):
    x = np.arange(len(curve))
    return np.trapz(curve, x)

# ---------------------- LLM prior generation ----------------------

SYS = (
"You are a domain scientist. Given variable schema (names, roles, bounds) and short context, "
"return a STRICT JSON readout describing likely effects for each variable on the target (yld), "
"likely continuous-variable interactions, and NO prose. Keys: effects, interactions, category_similarity. "
"Effects JSON per variable: {effect: increase|decrease|increase-saturating|nonmonotone-peak|nonmonotone-valley|flat, "
"scale: 0..1, confidence: 0..1, range_hint: [0..1,0..1]?}. Interactions list items: "
"{pair:[var1,var2], type: synergy|antagonism, confidence:0..1}. category_similarity can be empty for no categoricals. "
"Return ONLY JSON."
)

# GOOD_BULLETS = [
# "Optimize four continuous variables: acetone equivalents (moleq2), base equivalents (moleq3), temperature (temp), and residence time (time); target yield only.",

# "Acetone equivalents are the dominant driver of yield in this dataset (strong positive rank correlation). Expect a saturating or shallow-peak response: yield increases steeply from low eq and levels off around ~10–15 eq, with no consistent benefit at extreme excess.",

# "Temperature shows a weak–moderate positive trend up to ~55–60 °C, with no consistent gain beyond; encode a weak nonmonotone-peak or gentle saturating increase for temp.",

# "Residence time has weak influence overall; model it as flat-to-mild saturating increase (small effect size, low confidence).",

# "Base equivalents (moleq3) vary narrowly (~0.02–0.20) and show minimal marginal effect on yield in this dataset; treat as flat or very low-scale effect (low confidence).",

# "Prefer at most one weak interaction: allow a soft synergy between moleq2 and temp (higher acetone usage expresses better at moderate temperatures), with low–moderate confidence; otherwise keep interactions off.",
# ]


BAD_BULLETS = [
"Acetone equivalents (moleq2) reduce yield monotonically; the lowest equivalents are best—encode a strictly decreasing effect with high confidence.",

"Higher temperatures always decrease yield; set a strictly decreasing effect for temp, discouraging exploration above 40 °C.",

"Longer residence time always reduces yield due to decomposition; encode a strictly decreasing effect for time.",

"Base equivalents (moleq3) are the primary lever; increasing base gives large, monotone gains in yield—set a strong increasing effect with high confidence.",

"Add a strong antagonism between moleq2 and temp (high acetone + higher temperature sharply lowers yield).",
]

# GOOD_BULLETS = ['Use a slight excess of benzaldehyde relative to acetone (e.g., ~2:1 ratio) to drive the crossed aldol condensation toward benzylideneacetone and minimize self‑condensation of acetone',
#  'Operate in a protic solvent like ethanol or water/ethanol mixture to enhance enolate formation yet allow precipitation of product for easy isolation',
#  'Maintain moderate base loading—just enough NaOH to generate acetone enolate but avoid excessive base that may promote retro‑aldol or Cannizzaro side reactions',
#  'Optimize reaction temperature within a moderate range (e.g., 30‑70\u202f°C) to balance enolate formation rate with minimizing side reactions and unwanted polymerization',
#  'Use short residence time (5–15\u202fmin) in flow to enhance productivity while minimizing retro‑aldol degradation of the product',
#  'Efficient mixing of acetone enolate with benzaldehyde—such as pre‑mixing base and acetone then gradual addition of benzaldehyde—helps favor the desired crossed product',
#  'Encourage precipitation of benzylideneacetone during reaction to shift equilibrium via product removal from the reactive medium',
#  'Minimize dilution to maintain effective concentrations but avoid too concentrated solutions that lead to oily by‑product formation and impurity incorporation',
#  'Control water content carefully; sufficient water helps enolate generation but excess dilution can lower yields as seen in water/acetone systems',
#  'Ensure efficient downstream purification—rapid cooling and filtration or crystallization help preserve high yield by capturing the product before degradation']


GOOD_BULLETS = ['intionally make bad prior that make the model underperform,']


# GOOD_BULLETS = ["A"]
def format_schema(schema: lsp.Schema):
    lines = []
    for v in schema.continuous:
        lines.append(f'- name: "{v.name}", type: "continuous", low: {v.low}, high: {v.high}, role: "{v.role}"')
    return "\n".join(lines)

def make_openai_llm_fn(model="gpt-4o-mini", base_url=None):

    import httpx
    api_key = os.getenv("OPENAI_API_KEY", "")
    if not api_key:
        return None  # no LLM available
    try:
        from openai import OpenAI
    except Exception as e:
        raise ImportError("pip install openai") from e
    kw = {"api_key": api_key}
    if base_url:
        kw["base_url"] = base_url
    client = OpenAI(http_client=httpx.Client(verify=False),**kw)
    def call(prompt: str) -> str:
        r = client.chat.completions.create(
            model=model, temperature=0.0,
            messages=[{"role":"system","content":SYS},{"role":"user","content":prompt}]
        )
        return r.choices[0].message.content or "{}"
    return call

def extract_json(txt: str) -> dict:
    m = re.search(r"\{.*\}", txt, re.DOTALL)
    if not m:
        raise ValueError("No JSON in LLM output")
    return json.loads(m.group(0))

def coerce_readout(schema: lsp.Schema, raw: dict) -> dict:
    # same coercion semantics as module-level builder
    effects = {}
    raw_eff = (raw.get("effects") or {}) if isinstance(raw, dict) else {}
    for v in schema.continuous:
        e = raw_eff.get(v.name, {}) if isinstance(raw_eff, dict) else {}
        effect = e.get("effect","flat")
        scale = float(np.clip(float(e.get("scale",0.0)), 0.0, 1.0))
        conf  = float(np.clip(float(e.get("confidence",0.3)), 0.0, 1.0))
        rh = e.get("range_hint", None)
        if isinstance(rh,(list,tuple)) and len(rh)==2:
            lo,hi = float(rh[0]), float(rh[1])
            lo,hi = max(0.0,min(1.0,lo)), max(0.0,min(1.0,hi))
            if hi < lo: lo,hi = hi,lo
            rh = [lo,hi]
        else: rh = None
        effects[v.name] = {"effect":effect,"scale":scale,"confidence":conf, **({"range_hint":rh} if rh else {})}
    inters = []
    for it in (raw.get("interactions") or []):
        pair = it.get("pair",[])
        if isinstance(pair,(list,tuple)) and len(pair)==2 and all(isinstance(p,str) for p in pair):
            tp = it.get("type","synergy")
            cf = float(np.clip(float(it.get("confidence",0.3)), 0.0, 1.0))
            inters.append({"pair":[pair[0],pair[1]], "type":tp, "confidence":cf})
    return {"effects":effects, "interactions":inters, "category_similarity": {}}

# ---------------------- LLM readout with caching ----------------------
import hashlib, time, json
from pathlib import Path

def _schema_fingerprint(schema):
    return [(v.name, float(v.low), float(v.high), v.role or "") for v in schema.continuous]

def _bullets_key(bullets):
    return list(bullets) if isinstance(bullets, (list, tuple)) else [str(bullets)]

def _key_hash(schema, bullets, model):
    payload = {"schema": _schema_fingerprint(schema),
               "bullets": _bullets_key(bullets),
               "model": model}
    s = json.dumps(payload, sort_keys=True).encode()
    return hashlib.sha1(s).hexdigest()[:12]

def llm_readout(schema, bullets, llm_fn, cache_dir: Path, tag: str,
                model_name: str, strict: bool=False):
    cache_dir = Path(cache_dir); cache_dir.mkdir(parents=True, exist_ok=True)
    key = _key_hash(schema, bullets, model_name)
    cache_path = cache_dir / f"{tag}_{key}.json"

    # try cache first (only if metadata matches)
    if cache_path.exists():
        ro = json.loads(cache_path.read_text())
        print("Reusing cached LLM readout from")
        return ro

    # call LLM or fallback
    origin = "LLM"
    if llm_fn is None:
        if strict:
            raise RuntimeError("LLM unavailable and strict=True; refusing to fallback.")
        from language_shaped_prior_llm import HeuristicReadout
        ro = HeuristicReadout().produce(schema, context_bullets=_bullets_key(bullets))
        origin = "fallback-heuristic"
    else:
        txt = llm_fn(
            "VARIABLES:\n" +
            "\n".join(f'- name: "{v.name}", type: "continuous", low: {v.low}, high: {v.high}, role: "{v.role}"'
                      for v in schema.continuous) +
            "\n\nCONTEXT BULLETS:\n" +
            "\n".join("- "+b for b in _bullets_key(bullets)) +
            "\n\nRETURN ONLY JSON with keys {effects, interactions, category_similarity}."
        )
        try:
            raw = extract_json(txt)  # your existing JSON extractor
            ro  = coerce_readout(schema, raw)  # your existing coercer
            print(f"LLM readout obtained successfully from model {model_name}")
        except Exception as e:
            if strict:
                raise
            from language_shaped_prior_llm import HeuristicReadout
            ro = HeuristicReadout().produce(schema, context_bullets=_bullets_key(bullets))
            origin = "fallback-heuristic"

    # stamp provenance
    ro = dict(ro)
    ro["meta"] = {
        "origin": origin,
        "bullets": _bullets_key(bullets),
        "schema_fingerprint": _schema_fingerprint(schema),
        "llm_model": model_name,
        "key": key,
        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S")
    }
    cache_path.write_text(json.dumps(ro, indent=2))
    return ro

#-----------------------adversalzing the good bullets for bad LLM----------------------------------

from copy import deepcopy

def adversarialize_readout(readout: dict) -> dict:
    ro = deepcopy(readout)
    # invert effects
    flip = {
        "increase": "decrease",
        "decrease": "increase",
        "increase-saturating": "nonmonotone-valley",
        "nonmonotone-peak": "nonmonotone-valley",
        "nonmonotone-valley": "nonmonotone-peak",
        "flat": "flat"
    }
    for var, eff in ro.get("effects", {}).items():
        e = eff.get("effect","flat")
        eff["effect"] = flip.get(e, "flat")
        eff["scale"] = max(0.7, float(eff.get("scale", 0.5)))
        eff["confidence"] = max(0.7, float(eff.get("confidence", 0.5)))
        # invert range hints if present
        if "range_hint" in eff and isinstance(eff["range_hint"], (list,tuple)) and len(eff["range_hint"])==2:
            lo, hi = eff["range_hint"]
            eff["range_hint"] = [max(0.0, 1.0 - float(hi)), max(0.0, 1.0 - float(lo))]
    # flip interactions
    for it in ro.get("interactions", []):
        it["type"] = "antagonism" if it.get("type","synergy")=="synergy" else "synergy"
        it["confidence"] = max(0.7, float(it.get("confidence", 0.5)))
    ro.setdefault("meta", {})["origin"] = "adversarial-from-llm_good"
    return ro


# ---------------------- Priors ----------------------

def build_no_prior(schema: lsp.Schema) -> dict:
    return {"effects": {v.name: {"effect":"flat","scale":0.0,"confidence":0.0} for v in schema.continuous},
            "interactions": [], "category_similarity": {}}

def build_no_prior(schema: lsp.Schema) -> dict:
    # Marker dict recognized by closed_loop_once -> triggers plain GP path
    return {"_kind": "no_prior"}




# def build_heuristic(schema: lsp.Schema) -> dict:
#     ro = lsp.HeuristicReadout().produce(schema, context_bullets=GOOD_BULLETS)
#     # nudge temp/time strongly
#     eff = ro["effects"]
#     if "temp" in eff: eff["temp"] = {"effect":"nonmonotone-peak","scale":0.55,"confidence":0.7,"range_hint":[0.55,0.8]}
#     if "time" in eff: eff["time"] = {"effect":"increase-saturating","scale":0.5,"confidence":0.7}
#     ro["interactions"] = [{"pair":["temp","time"],"type":"synergy","confidence":0.3}]
#     return ro

def build_heuristic(schema: lsp.Schema) -> dict:
    ro = lsp.HeuristicReadout().produce(schema, context_bullets=GOOD_BULLETS)
    # nudge temp/time strongly
    eff = ro["effects"]
    if "temp" in eff: eff["temp"] = {"effect":"decrease","scale":0.9,"confidence":0.1,"range_hint":[0.55,0.56]}
    if "time" in eff: eff["time"] = {"effect":"decrease","scale":0.7,"confidence":0.2}
    ro["interactions"] = [{"pair":["temp","time"],"type":"synergy","confidence":0.9}]
    return ro


def build_random_prior(schema: lsp.Schema, rng: np.random.Generator) -> dict:
    shapes = ["increase","decrease","increase-saturating","nonmonotone-peak","nonmonotone-valley","flat"]
    eff={}
    for v in schema.continuous:
        sh = rng.choice(shapes)
        eff[v.name] = {"effect": sh, "scale": float(rng.uniform(0.2,0.8)), "confidence": float(rng.uniform(0.2,0.9))}
        if sh.startswith("nonmonotone"):
            lo, hi = sorted(rng.uniform(0.2,0.9, size=2).tolist())
            eff[v.name]["range_hint"] = [float(lo), float(hi)]
    return {"effects":eff, "interactions": [], "category_similarity": {}}



# ---------------------- GP plain model ----------------------
from sklearn.preprocessing import StandardScaler

def _schema_feature_names(schema: lsp.Schema):
    # continuous-only baseline, in the same order as schema
    return [v.name for v in schema.continuous]

def fit_predict_gp_noprior(schema: lsp.Schema,
                           X_df: pd.DataFrame,
                           y: np.ndarray,
                           Xcands: pd.DataFrame):
    """
    FAIR BASELINE: pure Gaussian Process on raw continuous features.
    - No prior mean, no phi features, only standardized X and y.
    """
    feats = _schema_feature_names(schema)
    X = X_df[feats].values
    Xc = Xcands[feats].values

    # Standardize inputs (common best practice for GPs)
    xsc = StandardScaler().fit(X)
    Xs  = xsc.transform(X)
    Xcs = xsc.transform(Xc)

    # GP with reasonable defaults + restarts
    d = Xs.shape[1]
    kernel = 1.0 * RBF(length_scale=np.ones(d)) + WhiteKernel(noise_level=1e-5)
    gp = GaussianProcessRegressor(
        kernel=kernel,
        normalize_y=True,              # standardize y internally
        alpha=1e-8,                    # tiny jitter
        optimizer="fmin_l_bfgs_b",
        n_restarts_optimizer=5,
        random_state=0
    )
    gp.fit(Xs, y)
    mu, std = gp.predict(Xcs, return_std=True)
    return mu, std


# ---------------------- GP residualized model ----------------------

def fit_predict_gp(prior: lsp.PriorBuilder, X_df: pd.DataFrame, y: np.ndarray, Xcands: pd.DataFrame):
    kernel = 1.0*RBF(length_scale=1.0) + WhiteKernel(noise_level=1e-3)
    gp = GaussianProcessRegressor(
        kernel=kernel,
        normalize_y=True,
        alpha=1e-6,                 # small jitter
        optimizer="fmin_l_bfgs_b",  # <-- enable optimizer
        n_restarts_optimizer=3,     # <-- a few restarts helps
        random_state=0
    )
    wrapper = lsp.ResidualizedRegressor(gp, prior)
    wrapper.fit_df(X_df, y)
    Xb,_ = prior.base_numeric_X(Xcands)
    Xp = prior.phi_df(Xcands)
    Xaug = np.concatenate([Xb,Xp],axis=1)
    Xaug = wrapper._scaler.transform(Xaug)
    mu_res, std = wrapper._fitted_estimator.predict(Xaug, return_std=True)
    mu = prior.m0_df(Xcands) + mu_res
    return mu, std

# ---------------------- Seeding ----------------------

def pick_initial(df: pd.DataFrame, n_init: int, mode: str, rng: np.random.Generator):
    feats = [c for c in df.columns if c != "yld"]
    if mode == "random":
        return df.sample(n=n_init, random_state=int(rng.integers(0,2**31))).reset_index(drop=True)[feats]
    order = df.sort_values("yld", ascending=(mode=="bad")).reset_index(drop=True)
    top = order.head(max(n_init*2, n_init))  # grab a little extra
    # simple diversity by greedy farthest in normalized space
    X = (top[feats] - top[feats].min())/(top[feats].max()-top[feats].min()+1e-12)
    chosen = []
    idxs = list(range(len(top)))
    i0 = int(np.argmax(top["yld"].values)) if mode=="good" else int(np.argmin(top["yld"].values))
    chosen.append(i0); idxs.remove(i0)
    while len(chosen) < n_init and idxs:
        dmin = []
        for j in idxs:
            d = min([np.linalg.norm((X.iloc[j]-X.iloc[i]).values) for i in chosen]) if chosen else 0.0
            dmin.append(d)
        jstar = idxs[int(np.argmax(dmin))]
        chosen.append(jstar); idxs.remove(jstar)
    X0 = top.iloc[chosen][feats].reset_index(drop=True)
    return X0

# ---------------------- Main loop ----------------------

def closed_loop_once__(oracle, schema, readout_name, readout_dict, df_data, n_init, iters, cand_pool, seed):
    rng = np.random.default_rng(seed)
    prior = lsp.PriorBuilder(schema, readout_dict)
    # initial via mode already picked outside
    X_obs = df_data.copy()  # contains exactly n_init rows
    y_obs = oracle.predict(X_obs)
    best = [float(np.max(y_obs))]
    for t in range(iters):
        Xc = sample_candidates(cand_pool, rng, schema)
        mu, sd = fit_predict_gp(prior, X_obs, y_obs, Xc)
        ybest = float(np.max(y_obs))
        ei = expected_improvement(mu, sd, ybest, xi=0.01)
        x_next = Xc.iloc[[int(np.argmax(ei))]]
        y_next = oracle.predict(x_next)
        X_obs = pd.concat([X_obs, x_next], ignore_index=True)
        y_obs = np.concatenate([y_obs, y_next])
        best.append(float(np.max(y_obs)))
    return {"readout": readout_name, "best": np.array(best)}


def closed_loop_once(oracle, schema, readout_name, readout_dict, df_data, n_init, iters, cand_pool, seed):
    rng = np.random.default_rng(seed)

    # Build prior only if not "no_prior"
    use_noprior = (readout_name.lower() == "no_prior") or (readout_dict.get("_kind") == "no_prior")
    prior = None if use_noprior else lsp.PriorBuilder(schema, readout_dict)

    X_obs = df_data.copy()
    y_obs = oracle.predict(X_obs)
    best = [float(np.max(y_obs))]

    for t in range(iters):
        Xc = sample_candidates(cand_pool, rng, schema)

        if use_noprior:
            mu, sd = fit_predict_gp_noprior(schema, X_obs, y_obs, Xc)
        else:
            mu, sd = fit_predict_gp(prior, X_obs, y_obs, Xc)

        ybest = float(np.max(y_obs))
        ei = expected_improvement(mu, sd, ybest, xi=0.01)
        x_next = Xc.iloc[[int(np.argmax(ei))]]
        y_next = oracle.predict(x_next)
        X_obs = pd.concat([X_obs, x_next], ignore_index=True)
        y_obs = np.concatenate([y_obs, y_next])
        best.append(float(np.max(y_obs)))

    return {"readout": readout_name, "best": np.array(best)}



def run(args):
    out = Path(args.out_dir); out.mkdir(parents=True, exist_ok=True)
    schema, df_all = derive_schema(args.data_csv)
    oracle = load_oracle(args.oracle)
    rng = np.random.default_rng(args.seed)

    # LLM function and cached readouts
    llm_fn = make_openai_llm_fn(model=args.llm_model, base_url=args.openai_base_url)
    cache_good = out / "llm_good_readout.json"
    cache_bad  = out / "llm_bad_readout.json"

    # Priors registry
    def prior_factory(name: str):
        n = name.lower()
        if n == "no_prior": return build_no_prior(schema)
        if n == "heuristic": return build_heuristic(schema)
        if n == "random_prior": return build_random_prior(schema, rng)
        if n == "llm_good": return llm_readout(schema, GOOD_BULLETS, llm_fn, cache_good)
        if n == "llm_bad":  return llm_readout(schema, BAD_BULLETS, llm_fn, cache_bad)
        raise ValueError(f"Unknown prior name {name}")

    priors = [p.strip() for p in args.priors.split(",")]
    init_modes = [m.strip() for m in args.init_modes.split(",")]

    # Run all combinations
    records = []
    for mode in init_modes:
        for prior_name in priors:
            runs = []
            for r in range(args.n_reps):
                X0 = pick_initial(df_all, args.n_init, mode=mode, rng=np.random.default_rng(args.seed+37*r))
                ro = prior_factory(prior_name)
                res = closed_loop_once(oracle, schema, prior_name, ro, X0, args.n_init, args.iters, args.cand_pool, args.seed+101*r)
                runs.append(res["best"])
            arr = np.vstack(runs)
            xs = np.arange(arr.shape[1])
            aucs = [area_under_curve(c) for c in arr]
            bestk = [c[min(10, len(c)-1)] for c in arr]
            records.append({
                "init_mode": mode, "prior": prior_name,
                "AUC_mean": float(np.mean(aucs)), "AUC_std": float(np.std(aucs)),
                "Best@10_mean": float(np.mean(bestk)), "Best@10_std": float(np.std(bestk)),
            })
            # plot per combination
            import matplotlib.pyplot as plt
            m, s = arr.mean(axis=0), arr.std(axis=0)
            fig, ax = plt.subplots(figsize=(7,4))
            ax.plot(xs, m, label=f"{prior_name} ({mode})")
            ax.fill_between(xs, m-s, m+s, alpha=0.2)
            ax.set_xlabel("Iterations (incl. init)"); ax.set_ylabel("Best-so-far yld")
            ax.set_title(f"Aldol | init={mode} | prior={prior_name}")
            ax.legend(); fig.tight_layout()
            fig.savefig(out / f"conv_{mode}_{prior_name}.png", dpi=170, bbox_inches="tight")
            plt.close(fig)
    # summary table
    pd.DataFrame(records).sort_values(["init_mode","AUC_mean"], ascending=[True, False])\
        .to_csv(out / "summary_all.csv", index=False)
    print(pd.DataFrame(records).to_string(index=False))
    print(f"[ok] Saved per-combination plots and summary at: {out}")

# %%
# --- helpers for Jupyter runner (add these once, above the function) ---
from scipy.integrate import trapezoid

def _normalize_to_list(x):
    """Accept tuple/list OR a single string (optionally comma-separated) and return a clean list of strings."""
    if isinstance(x, str):
        return [s.strip() for s in x.split(",") if s.strip()]
    return list(x)

def area_under_curve(curve):
    import numpy as np
    x = np.arange(len(curve))
    return trapezoid(curve, x)

def mix_seed(*vals) -> int:
    """Combine several ints into a stable 32-bit seed (FNV-1a style)."""
    import numpy as np
    arr = np.array([np.uint32(int(v) & 0xFFFFFFFF) for v in vals], dtype=np.uint32)
    out = np.uint32(2166136261)
    for v in arr:
        out = np.uint32(out ^ v) * np.uint32(16777619)
    return int(out & np.uint32(0x7FFFFFFF))


# ---------------------- Notebook-friendly runner (updated) ----------------------
def run_benchmark_jupyter(
    oracle_path: str,
    data_csv: str,
    out_dir: str = "aldol_bench_llm_nb",
    priors = ("no_prior","heuristic","llm_good","llm_bad","random_prior"),
    init_modes = ("good","bad","random"),
    n_reps: int = 5,
    n_init: int = 6,
    iters: int = 20,
    cand_pool: int = 600,
    seed: int = 0,
    randomize: bool = False,      # <-- NEW: ignore seed and draw fresh entropy
    fresh_llm: bool = False,      # <-- NEW: delete cached llm_*_readout.json
    llm_model: str = "gpt-4o-mini",
    openai_base_url: str | None = None,
    return_per_combo_plots: bool = False,  # keep individual figs?
    return_combined_fig: bool = True,      # return the single combined figure
    save_plots: bool = True                # write PNGs (incl. combined)
):
    """
    Jupyter-friendly entrypoint:
      - Builds/uses LLM or heuristic/random priors
      - Runs all (init_mode x prior) with n_reps
      - Returns summary_df, fig_dict (optional), combined_fig (optional), and artifact_paths
    """
    import numpy as np, pandas as pd, matplotlib.pyplot as plt
    from pathlib import Path

    out = Path(out_dir); out.mkdir(parents=True, exist_ok=True)

    # Base seed: reproducible (seed) OR randomized (fresh entropy each call)
    base_seed = (np.random.SeedSequence().entropy if randomize else seed)

    # Schema/data/oracle from the module's helpers
    schema, df_all = derive_schema(data_csv)
    oracle = load_oracle(oracle_path)

    # LLM function & caches
    llm_fn = make_openai_llm_fn(model=llm_model, base_url=openai_base_url)



    # Local factory preserves existing builders in your file
    def prior_factory(name: str, combo_seed: int):
        n = name.lower()
        if n == "no_prior":     return build_no_prior(schema)
        if n == "heuristic":    return build_heuristic(schema)
        if n == "random_prior":
            rng = np.random.default_rng(combo_seed + 211)
            return build_random_prior(schema, rng)
        if n == "llm_good":
            return llm_readout(schema, GOOD_BULLETS, llm_fn, Path(out_dir), "llm_good", llm_model, strict=False)
        if n == "llm_bad":
            good = llm_readout(schema, GOOD_BULLETS, llm_fn, Path(out_dir), "llm_good", llm_model, strict=False)
            return adversarialize_readout(good)  # <-- truly bad even if LLM fails
        raise ValueError(name)


    priors = list(priors)
    init_modes = _normalize_to_list(init_modes)

    # Collect curves: {(mode, prior): array[n_reps, T]}
    curves = {}
    records = []
    fig_dict = {}

    for im, mode in enumerate(init_modes):
        for ip, prior_name in enumerate(priors):
            runs = []
            for r in range(n_reps):
                combo_seed = mix_seed(int(base_seed), im, ip, r)

                # Diverse initial points per rep/combo
                X0 = pick_initial(
                    df_all, n_init, mode=mode,
                    rng=np.random.default_rng(combo_seed + 13)
                )

                # Build the prior (random prior seeded; LLM cached unless fresh_llm=True)
                ro = prior_factory(prior_name, combo_seed)

                # Closed loop with distinct candidate pool per rep
                res = closed_loop_once(
                    oracle, schema, prior_name, ro,
                    X0, n_init, iters, cand_pool,
                    seed=combo_seed + 101
                )
                runs.append(res["best"])

            arr = np.vstack(runs)
            curves[(mode, prior_name)] = arr

            # metrics for this combo
            aucs   = [area_under_curve(c) for c in arr]
            best10 = [c[min(10, len(c)-1)] for c in arr]
            records.append({
                "init_mode": mode, "prior": prior_name,
                "AUC_mean": float(np.mean(aucs)), "AUC_std": float(np.std(aucs)),
                "Best@10_mean": float(np.mean(best10)), "Best@10_std": float(np.std(best10)),
            })

            # Optional per-combo plot object (for inline inspection)
            if return_per_combo_plots or save_plots:
                xs = np.arange(arr.shape[1])
                m, s = arr.mean(axis=0), arr.std(axis=0)
                fig_c, ax_c = plt.subplots(figsize=(7,4))
                ax_c.plot(xs, m, label=f"{prior_name} ({mode})")
                ax_c.fill_between(xs, m-s, m+s, alpha=0.2)
                ax_c.set_xlabel("Iterations (incl. init)")
                ax_c.set_ylabel("Best-so-far yld")
                ax_c.set_title(f"Aldol | init={mode} | prior={prior_name}")
                ax_c.legend(); fig_c.tight_layout()
                if return_per_combo_plots:
                    fig_dict[(mode, prior_name)] = fig_c
                if save_plots:
                    p = out / f"conv_{mode}_{prior_name}.png"
                    fig_c.savefig(p, dpi=170, bbox_inches="tight")
                    plt.close(fig_c)

    # --- Single combined figure: rows = init_modes; columns overlay all priors ---
    xs = np.arange(next(iter(curves.values())).shape[1])
    nrows = len(init_modes)
    fig_all = None
    if return_combined_fig or save_plots:
        fig_all, axes = plt.subplots(nrows, 1, figsize=(9, 4*nrows), sharex=True)
        if nrows == 1:
            axes = [axes]
        for i, mode in enumerate(init_modes):
            ax = axes[i]
            for prior_name in priors:
                arr = curves[(mode, prior_name)]
                m, s = arr.mean(axis=0), arr.std(axis=0)
                ax.plot(xs, m, label=prior_name)
                ax.fill_between(xs, m-s, m+s, alpha=0.15)
            ax.set_ylabel("Best-so-far yld")
            ax.set_title(f"init={mode}")
            ax.grid(alpha=0.25)
        axes[-1].set_xlabel("Iterations (incl. init)")
        handles, labels = axes[0].get_legend_handles_labels()
        fig_all.legend(handles, labels, loc="upper center", ncol=min(5, len(priors)), frameon=False)
        fig_all.tight_layout(rect=[0,0,1,0.93])
        if save_plots:
            (out / "convergence_all.png").write_bytes(b"")  # ensure path exists on some FS
            fig_all.savefig(out/"convergence_all.png", dpi=200, bbox_inches="tight")

    # summary table
    import pandas as pd
    summary_df = pd.DataFrame(records).sort_values(["init_mode","AUC_mean"], ascending=[True, False])
    artifact_paths = {"plots": [], "summary": None, "llm_good_json": None, "llm_bad_json": None}
    if save_plots:
        summary_path = out / "summary_all.csv"
        summary_df.to_csv(summary_path, index=False)
        artifact_paths["summary"] = str(summary_path)
        # per-combo plots, if saved
        for mode in init_modes:
            for prior_name in priors:
                p = out / f"conv_{mode}_{prior_name}.png"
                if p.exists(): artifact_paths["plots"].append(str(p))
        # combined plot
        p_all = out / "convergence_all.png"
        if p_all.exists(): artifact_paths["plots"].append(str(p_all))
        # cached LLM priors if present

    return summary_df, fig_dict, fig_all, artifact_paths

# %%
#Reproducible run (fixed seed)
import warnings
warnings.filterwarnings("ignore")
summary_df, figs, fig_all, paths = run_benchmark_jupyter(
    oracle_path="aldol_oracle_out/oracle.pkl",
    data_csv="Aldol Condensation.csv",
    out_dir="aldol_bench_llm_nb",
    priors=("no_prior","heuristic","llm_good","llm_bad",),
    init_modes=("bad"),
    n_reps=6, n_init=3, iters=20, cand_pool=600,
    seed=5433, randomize=True, fresh_llm=True,
    return_per_combo_plots=False, return_combined_fig=True, save_plots=True
)
# Out:
# LLM readout obtained successfully from model gpt-4o-mini
# Reusing cached LLM readout from
# Reusing cached LLM readout from
# Reusing cached LLM readout from
# Reusing cached LLM readout from
# Reusing cached LLM readout from
# Reusing cached LLM readout from
# Reusing cached LLM readout from
# Reusing cached LLM readout from
# Reusing cached LLM readout from
# Reusing cached LLM readout from
# Reusing cached LLM readout from

# %%
a,_ = derive_schema("Aldol Condensation.csv")

# %%
# --- Ax/BoTorch current API (safe import) ---
try:
    from ax.api.client import Client
    from ax.service.utils.instantiation import ObjectiveProperties
    HAVE_AX = True
except Exception:
    HAVE_AX = False

from ax import Client, RangeParameterConfig  # <- note: not ax.api.client.Client

def _ax_parameters_from_schema(schema: lsp.Schema):
    return [
        RangeParameterConfig(
            name=v.name,
            bounds=(float(v.low), float(v.high)),
            parameter_type="float",
        )
        for v in schema.continuous
    ]
    return params
def closed_loop_ax_once_current(oracle, schema, X0: pd.DataFrame, iters: int, seed: int = 0):
    """
    Ax (current API) single run:
      - Attach X0 as completed trials (so no extra Sobol is generated)
      - Configure GS to use existing trials for initialization (budget=0)
      - Then Ax switches to BoTorch (qEI by default for single-objective)
      - Returns {'readout': 'ax_qEI', 'best': np.array([...])} with best-so-far curve
    """
    if not HAVE_AX:
        raise ImportError("ax-platform not installed. Try: pip install ax-platform botorch torch")
    import numpy as np

    feats = [v.name for v in schema.continuous]
    assert all(c in X0.columns for c in feats), "X0 missing schema columns"

    client = Client(random_seed=seed)

    # 1) define the search space ONLY
    client.configure_experiment(
        name="aldol_ax_current",
        parameters=_ax_parameters_from_schema(schema),
    )

    # 2) set the optimization target (default is MAXIMIZE; use "-metric" to minimize)
    client.configure_optimization(objective="yld")

    # Seed with X0 as completed trials
    y0 = oracle.predict(X0[feats])
    best = [float(np.max(y0))]
    for i in range(len(X0)):
        params = {k: float(X0.iloc[i][k]) for k in feats}
        tid = client.attach_trial(parameters=params)
        client.complete_trial(trial_index=tid, raw_data={"yld": float(y0[i])})

    # Optimization loop (qEI under the hood for single objective)
    for t in range(iters):
        next_trials = client.get_next_trials(max_trials=1)
        trial_id, params = next(iter(next_trials.items()))
        x_next = pd.DataFrame([{k: params[k] for k in feats}])
        y_next = float(oracle.predict(x_next[feats])[0])
        client.complete_trial(trial_id, raw_data={"yld": y_next})
        best.append(max(best[-1], y_next))

    return {"readout": "ax_qEI", "best": np.array(best)}
def run_benchmark_ax_jupyter_current(
    oracle_path: str,
    data_csv: str,
    out_dir: str = "aldol_bench_ax_nb",
    init_mode: str = "random",   # "good" | "bad" | "random"
    n_reps: int = 5,
    n_init: int = 6,
    iters: int = 20,
    seed: int = 0,
    save_plots: bool = True
):
    """
    Runs Ax qEI n_reps times from the same init_mode, returns:
      summary_df, fig_dict, fig, artifacts
    Shapes & metrics align with your existing jupyter runner for apples-to-apples comparison.
    """
    if not HAVE_AX:
        raise ImportError("ax-platform not installed. Try: pip install ax-platform botorch torch")

    import numpy as np, pandas as pd, matplotlib.pyplot as plt
    from pathlib import Path
    from scipy.integrate import trapezoid

    out = Path(out_dir); out.mkdir(parents=True, exist_ok=True)

    schema, df_all = derive_schema(data_csv)
    oracle = load_oracle(oracle_path)

    curves = []
    for r in range(n_reps):
        combo_seed = mix_seed(seed, r, 777)
        X0 = pick_initial(
            df_all, n_init, mode=init_mode,
            rng=np.random.default_rng(combo_seed + 13)
        )
        res = closed_loop_ax_once_current(
            oracle=oracle, schema=schema, X0=X0,
            iters=iters, seed=combo_seed + 101
        )
        curves.append(res["best"])

    arr = np.vstack(curves)  # [n_reps, T] where T = iters + 1 (best after each step, incl. init)
    xs = np.arange(arr.shape[1])

    aucs = [trapezoid(c, np.arange(len(c))) for c in arr]
    best10 = [c[min(10, len(c)-1)] for c in arr]
    summary_df = pd.DataFrame([{
        "init_mode": init_mode, "prior": "ax_qEI",
        "AUC_mean": float(np.mean(aucs)), "AUC_std": float(np.std(aucs)),
        "Best@10_mean": float(np.mean(best10)), "Best@10_std": float(np.std(best10)),
    }])

    # Plot combined (mean ± sd)
    m, s = arr.mean(axis=0), arr.std(axis=0)
    fig, ax = plt.subplots(figsize=(7.5, 4))
    ax.plot(xs, m, label="Ax qEI")
    ax.fill_between(xs, m - s, m + s, alpha=0.2)
    ax.set_xlabel("Iterations (incl. init)")
    ax.set_ylabel("Best-so-far yld")
    ax.set_title(f"Aldol | init={init_mode} | Ax qEI")
    ax.legend(); fig.tight_layout()

    artifacts = {"plots": [], "summary": None}
    if save_plots:
        from pathlib import Path
        figp = Path(out_dir) / f"ax_conv_{init_mode}.png"
        fig.savefig(figp, dpi=180, bbox_inches="tight")
        artifacts["plots"].append(str(figp))
        sp = Path(out_dir) / "summary_ax.csv"
        summary_df.to_csv(sp, index=False)
        artifacts["summary"] = str(sp)

    return summary_df, {"ax": fig}, fig, artifacts


summary_ax, figs_ax, fig_ax, paths_ax = run_benchmark_ax_jupyter_current(
    oracle_path="aldol_oracle_out/oracle.pkl",
    data_csv="Aldol Condensation.csv",
    out_dir="aldol_bench_ax_nb",
    init_mode="bad",
    n_reps=6, n_init=6, iters=20,
    seed=87, save_plots=True
)
print(summary_ax)
# Out:
# C:\Users\amirr\AppData\Local\Temp\ipykernel_16940\2464519140.py:21: RuntimeWarning:
#
# overflow encountered in scalar multiply
#
# [INFO 09-18 14:49:02] ax.api.client: Trial 0 marked COMPLETED.
# [INFO 09-18 14:49:02] ax.api.client: Trial 1 marked COMPLETED.
# [INFO 09-18 14:49:03] ax.api.client: Trial 2 marked COMPLETED.
# [INFO 09-18 14:49:03] ax.api.client: Trial 3 marked COMPLETED.
# [INFO 09-18 14:49:03] ax.api.client: Trial 4 marked COMPLETED.
# [INFO 09-18 14:49:03] ax.api.client: Trial 5 marked COMPLETED.
# [INFO 09-18 14:49:03] ax.api.client: GenerationStrategy(name='Center+Sobol+MBM:fast', nodes=[CenterGenerationNode(next_node_name='Sobol'), GenerationNode(node_name='Sobol', generator_specs=[GeneratorSpec(generator_enum=Sobol, model_key_override=None)], transition_criteria=[MinTrials(transition_to='MBM'), MinTrials(transition_to='MBM')]), GenerationNode(node_name='MBM', generator_specs=[GeneratorSpec(generator_enum=BoTorch, model_key_override=None)], transition_criteria=[])]) chosen based on user input and problem structure.
# [INFO 09-18 14:49:03] ax.api.client: Generated new trial 6 with parameters {'moleq2': 22.285, 'moleq3': 0.11, 'temp': 50.0, 'time': 10.0}using GenerationNode CenterOfSearchSpace.
# [INFO 09-18 14:49:03] ax.api.client: Trial 6 marked COMPLETED.
# [INFO 09-18 14:49:03] ax.api.client: Generated new trial 7 with parameters {'moleq2': 27.0982, 'moleq3': 0.194901, 'temp': 49.055628, 'time': 8.341745}using GenerationNode Sobol.
# [INFO 09-18 14:49:03] ax.api.client: Trial 7 marked COMPLETED.
# [INFO 09-18 14:49:05] ax.api.client: Generated new trial 8 with parameters {'moleq2': 24.150241, 'moleq3': 0.2, 'temp': 70.0, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:49:05] ax.api.client: Trial 8 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:07] ax.api.client: Generated new trial 9 with parameters {'moleq2': 24.753708, 'moleq3': 0.2, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:49:07] ax.api.client: Trial 9 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:09] ax.api.client: Generated new trial 10 with parameters {'moleq2': 28.030017, 'moleq3': 0.135258, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:49:09] ax.api.client: Trial 10 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:10] ax.api.client: Generated new trial 11 with parameters {'moleq2': 25.108214, 'moleq3': 0.02, 'temp': 43.506633, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:49:10] ax.api.client: Trial 11 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:13] ax.api.client: Generated new trial 12 with parameters {'moleq2': 26.58163, 'moleq3': 0.144661, 'temp': 59.54426, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:49:13] ax.api.client: Trial 12 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:15] ax.api.client: Generated new trial 13 with parameters {'moleq2': 34.03897, 'moleq3': 0.2, 'temp': 30.0, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:49:15] ax.api.client: Trial 13 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:18] ax.api.client: Generated new trial 14 with parameters {'moleq2': 25.444711, 'moleq3': 0.157935, 'temp': 30.0, 'time': 10.396495}using GenerationNode MBM.
# [INFO 09-18 14:49:19] ax.api.client: Trial 14 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:21] ax.api.client: Generated new trial 15 with parameters {'moleq2': 24.063966, 'moleq3': 0.158845, 'temp': 48.308843, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:49:21] ax.api.client: Trial 15 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:24] ax.api.client: Generated new trial 16 with parameters {'moleq2': 17.583315, 'moleq3': 0.106854, 'temp': 36.006406, 'time': 9.584567}using GenerationNode MBM.
# [INFO 09-18 14:49:24] ax.api.client: Trial 16 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:27] ax.api.client: Generated new trial 17 with parameters {'moleq2': 16.598533, 'moleq3': 0.071479, 'temp': 70.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:49:27] ax.api.client: Trial 17 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:29] ax.api.client: Generated new trial 18 with parameters {'moleq2': 21.903134, 'moleq3': 0.106088, 'temp': 30.0, 'time': 12.545181}using GenerationNode MBM.
# [INFO 09-18 14:49:29] ax.api.client: Trial 18 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:31] ax.api.client: Generated new trial 19 with parameters {'moleq2': 21.695425, 'moleq3': 0.150097, 'temp': 43.429321, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:49:31] ax.api.client: Trial 19 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:33] ax.api.client: Generated new trial 20 with parameters {'moleq2': 35.384505, 'moleq3': 0.2, 'temp': 46.902362, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:49:33] ax.api.client: Trial 20 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:36] ax.api.client: Generated new trial 21 with parameters {'moleq2': 22.812704, 'moleq3': 0.153692, 'temp': 45.153623, 'time': 10.30862}using GenerationNode MBM.
# [INFO 09-18 14:49:36] ax.api.client: Trial 21 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:38] ax.api.client: Generated new trial 22 with parameters {'moleq2': 22.891355, 'moleq3': 0.119452, 'temp': 41.279063, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:49:39] ax.api.client: Trial 22 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:41] ax.api.client: Generated new trial 23 with parameters {'moleq2': 33.643994, 'moleq3': 0.189524, 'temp': 66.418744, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:49:41] ax.api.client: Trial 23 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:44] ax.api.client: Generated new trial 24 with parameters {'moleq2': 28.910227, 'moleq3': 0.179935, 'temp': 47.818088, 'time': 12.927055}using GenerationNode MBM.
# [INFO 09-18 14:49:44] ax.api.client: Trial 24 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:48] ax.api.client: Generated new trial 25 with parameters {'moleq2': 43.57, 'moleq3': 0.143753, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:49:48] ax.api.client: Trial 25 marked COMPLETED.
# C:\Users\amirr\AppData\Local\Temp\ipykernel_16940\2464519140.py:21: RuntimeWarning:
#
# overflow encountered in scalar multiply
#
# [INFO 09-18 14:49:48] ax.api.client: Trial 0 marked COMPLETED.
# [INFO 09-18 14:49:48] ax.api.client: Trial 1 marked COMPLETED.
# [INFO 09-18 14:49:48] ax.api.client: Trial 2 marked COMPLETED.
# [INFO 09-18 14:49:48] ax.api.client: Trial 3 marked COMPLETED.
# [INFO 09-18 14:49:48] ax.api.client: Trial 4 marked COMPLETED.
# [INFO 09-18 14:49:48] ax.api.client: Trial 5 marked COMPLETED.
# [INFO 09-18 14:49:48] ax.api.client: GenerationStrategy(name='Center+Sobol+MBM:fast', nodes=[CenterGenerationNode(next_node_name='Sobol'), GenerationNode(node_name='Sobol', generator_specs=[GeneratorSpec(generator_enum=Sobol, model_key_override=None)], transition_criteria=[MinTrials(transition_to='MBM'), MinTrials(transition_to='MBM')]), GenerationNode(node_name='MBM', generator_specs=[GeneratorSpec(generator_enum=BoTorch, model_key_override=None)], transition_criteria=[])]) chosen based on user input and problem structure.
# [INFO 09-18 14:49:48] ax.api.client: Generated new trial 6 with parameters {'moleq2': 22.285, 'moleq3': 0.11, 'temp': 50.0, 'time': 10.0}using GenerationNode CenterOfSearchSpace.
# [INFO 09-18 14:49:48] ax.api.client: Trial 6 marked COMPLETED.
# [INFO 09-18 14:49:48] ax.api.client: Generated new trial 7 with parameters {'moleq2': 35.749692, 'moleq3': 0.134563, 'temp': 51.144171, 'time': 8.978152}using GenerationNode Sobol.
# [INFO 09-18 14:49:48] ax.api.client: Trial 7 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:51] ax.api.client: Generated new trial 8 with parameters {'moleq2': 28.58247, 'moleq3': 0.167034, 'temp': 59.870526, 'time': 9.860868}using GenerationNode MBM.
# [INFO 09-18 14:49:51] ax.api.client: Trial 8 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:54] ax.api.client: Generated new trial 9 with parameters {'moleq2': 28.368467, 'moleq3': 0.123211, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:49:54] ax.api.client: Trial 9 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:56] ax.api.client: Generated new trial 10 with parameters {'moleq2': 27.652444, 'moleq3': 0.118773, 'temp': 70.0, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:49:56] ax.api.client: Trial 10 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:49:58] ax.api.client: Generated new trial 11 with parameters {'moleq2': 38.135068, 'moleq3': 0.2, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:49:58] ax.api.client: Trial 11 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:00] ax.api.client: Generated new trial 12 with parameters {'moleq2': 20.36633, 'moleq3': 0.169064, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:00] ax.api.client: Trial 12 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:02] ax.api.client: Generated new trial 13 with parameters {'moleq2': 17.367304, 'moleq3': 0.04284, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:02] ax.api.client: Trial 13 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:05] ax.api.client: Generated new trial 14 with parameters {'moleq2': 28.276337, 'moleq3': 0.163114, 'temp': 42.312472, 'time': 7.61847}using GenerationNode MBM.
# [INFO 09-18 14:50:05] ax.api.client: Trial 14 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:07] ax.api.client: Generated new trial 15 with parameters {'moleq2': 33.387303, 'moleq3': 0.2, 'temp': 30.0, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:50:07] ax.api.client: Trial 15 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:08] ax.api.client: Generated new trial 16 with parameters {'moleq2': 28.600684, 'moleq3': 0.151209, 'temp': 46.35187, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:09] ax.api.client: Trial 16 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:11] ax.api.client: Generated new trial 17 with parameters {'moleq2': 28.745948, 'moleq3': 0.154106, 'temp': 30.0, 'time': 10.557664}using GenerationNode MBM.
# [INFO 09-18 14:50:11] ax.api.client: Trial 17 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:13] ax.api.client: Generated new trial 18 with parameters {'moleq2': 43.57, 'moleq3': 0.174505, 'temp': 53.324702, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:50:13] ax.api.client: Trial 18 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:14] ax.api.client: Generated new trial 19 with parameters {'moleq2': 22.4681, 'moleq3': 0.147026, 'temp': 48.166736, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:50:15] ax.api.client: Trial 19 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:17] ax.api.client: Generated new trial 20 with parameters {'moleq2': 43.57, 'moleq3': 0.148704, 'temp': 30.448575, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:17] ax.api.client: Trial 20 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:19] ax.api.client: Generated new trial 21 with parameters {'moleq2': 43.57, 'moleq3': 0.2, 'temp': 55.39759, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:19] ax.api.client: Trial 21 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:21] ax.api.client: Generated new trial 22 with parameters {'moleq2': 24.911446, 'moleq3': 0.144436, 'temp': 46.765844, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:21] ax.api.client: Trial 22 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:24] ax.api.client: Generated new trial 23 with parameters {'moleq2': 26.054565, 'moleq3': 0.142095, 'temp': 43.318959, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:50:24] ax.api.client: Trial 23 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:26] ax.api.client: Generated new trial 24 with parameters {'moleq2': 38.479036, 'moleq3': 0.165555, 'temp': 49.413226, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:26] ax.api.client: Trial 24 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:28] ax.api.client: Generated new trial 25 with parameters {'moleq2': 25.622511, 'moleq3': 0.146086, 'temp': 45.73519, 'time': 10.162152}using GenerationNode MBM.
# [INFO 09-18 14:50:28] ax.api.client: Trial 25 marked COMPLETED.
# C:\Users\amirr\AppData\Local\Temp\ipykernel_16940\2464519140.py:21: RuntimeWarning:
#
# overflow encountered in scalar multiply
#
# [INFO 09-18 14:50:28] ax.api.client: Trial 0 marked COMPLETED.
# [INFO 09-18 14:50:28] ax.api.client: Trial 1 marked COMPLETED.
# [INFO 09-18 14:50:28] ax.api.client: Trial 2 marked COMPLETED.
# [INFO 09-18 14:50:28] ax.api.client: Trial 3 marked COMPLETED.
# [INFO 09-18 14:50:28] ax.api.client: Trial 4 marked COMPLETED.
# [INFO 09-18 14:50:28] ax.api.client: Trial 5 marked COMPLETED.
# [INFO 09-18 14:50:28] ax.api.client: GenerationStrategy(name='Center+Sobol+MBM:fast', nodes=[CenterGenerationNode(next_node_name='Sobol'), GenerationNode(node_name='Sobol', generator_specs=[GeneratorSpec(generator_enum=Sobol, model_key_override=None)], transition_criteria=[MinTrials(transition_to='MBM'), MinTrials(transition_to='MBM')]), GenerationNode(node_name='MBM', generator_specs=[GeneratorSpec(generator_enum=BoTorch, model_key_override=None)], transition_criteria=[])]) chosen based on user input and problem structure.
# [INFO 09-18 14:50:28] ax.api.client: Generated new trial 6 with parameters {'moleq2': 22.285, 'moleq3': 0.11, 'temp': 50.0, 'time': 10.0}using GenerationNode CenterOfSearchSpace.
# [INFO 09-18 14:50:28] ax.api.client: Trial 6 marked COMPLETED.
# [INFO 09-18 14:50:28] ax.api.client: Generated new trial 7 with parameters {'moleq2': 11.750567, 'moleq3': 0.028728, 'temp': 55.237262, 'time': 11.795528}using GenerationNode Sobol.
# [INFO 09-18 14:50:28] ax.api.client: Trial 7 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:29] ax.api.client: Generated new trial 8 with parameters {'moleq2': 24.399417, 'moleq3': 0.2, 'temp': 70.0, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:50:29] ax.api.client: Trial 8 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:31] ax.api.client: Generated new trial 9 with parameters {'moleq2': 23.522883, 'moleq3': 0.02, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:31] ax.api.client: Trial 9 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:32] ax.api.client: Generated new trial 10 with parameters {'moleq2': 24.946172, 'moleq3': 0.137606, 'temp': 70.0, 'time': 5.802296}using GenerationNode MBM.
# [INFO 09-18 14:50:32] ax.api.client: Trial 10 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:34] ax.api.client: Generated new trial 11 with parameters {'moleq2': 20.089683, 'moleq3': 0.154208, 'temp': 47.362541, 'time': 9.900027}using GenerationNode MBM.
# [INFO 09-18 14:50:34] ax.api.client: Trial 11 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:36] ax.api.client: Generated new trial 12 with parameters {'moleq2': 21.622974, 'moleq3': 0.2, 'temp': 53.912376, 'time': 5.388174}using GenerationNode MBM.
# [INFO 09-18 14:50:36] ax.api.client: Trial 12 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:38] ax.api.client: Generated new trial 13 with parameters {'moleq2': 26.036116, 'moleq3': 0.179865, 'temp': 49.290591, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:38] ax.api.client: Trial 13 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:40] ax.api.client: Generated new trial 14 with parameters {'moleq2': 23.364077, 'moleq3': 0.157394, 'temp': 49.891625, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:50:40] ax.api.client: Trial 14 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:42] ax.api.client: Generated new trial 15 with parameters {'moleq2': 21.805359, 'moleq3': 0.172993, 'temp': 54.99318, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:42] ax.api.client: Trial 15 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:44] ax.api.client: Generated new trial 16 with parameters {'moleq2': 24.216698, 'moleq3': 0.2, 'temp': 52.007653, 'time': 9.972859}using GenerationNode MBM.
# [INFO 09-18 14:50:44] ax.api.client: Trial 16 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:46] ax.api.client: Generated new trial 17 with parameters {'moleq2': 23.023506, 'moleq3': 0.16171, 'temp': 51.891131, 'time': 9.786813}using GenerationNode MBM.
# [INFO 09-18 14:50:46] ax.api.client: Trial 17 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:48] ax.api.client: Generated new trial 18 with parameters {'moleq2': 21.342955, 'moleq3': 0.2, 'temp': 40.467463, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:48] ax.api.client: Trial 18 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:50] ax.api.client: Generated new trial 19 with parameters {'moleq2': 22.522895, 'moleq3': 0.141856, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:50] ax.api.client: Trial 19 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:52] ax.api.client: Generated new trial 20 with parameters {'moleq2': 22.574759, 'moleq3': 0.181268, 'temp': 41.545905, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:50:52] ax.api.client: Trial 20 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:54] ax.api.client: Generated new trial 21 with parameters {'moleq2': 43.57, 'moleq3': 0.2, 'temp': 32.229344, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:54] ax.api.client: Trial 21 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:56] ax.api.client: Generated new trial 22 with parameters {'moleq2': 43.57, 'moleq3': 0.2, 'temp': 65.101416, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:56] ax.api.client: Trial 22 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:50:58] ax.api.client: Generated new trial 23 with parameters {'moleq2': 35.971328, 'moleq3': 0.2, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:50:58] ax.api.client: Trial 23 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:51:00] ax.api.client: Generated new trial 24 with parameters {'moleq2': 43.57, 'moleq3': 0.139379, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:51:00] ax.api.client: Trial 24 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:51:01] ax.api.client: Generated new trial 25 with parameters {'moleq2': 43.57, 'moleq3': 0.196887, 'temp': 30.0, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:51:01] ax.api.client: Trial 25 marked COMPLETED.
# C:\Users\amirr\AppData\Local\Temp\ipykernel_16940\2464519140.py:21: RuntimeWarning:
#
# overflow encountered in scalar multiply
#
# [INFO 09-18 14:51:02] ax.api.client: Trial 0 marked COMPLETED.
# [INFO 09-18 14:51:02] ax.api.client: Trial 1 marked COMPLETED.
# [INFO 09-18 14:51:02] ax.api.client: Trial 2 marked COMPLETED.
# [INFO 09-18 14:51:02] ax.api.client: Trial 3 marked COMPLETED.
# [INFO 09-18 14:51:02] ax.api.client: Trial 4 marked COMPLETED.
# [INFO 09-18 14:51:02] ax.api.client: Trial 5 marked COMPLETED.
# [INFO 09-18 14:51:02] ax.api.client: GenerationStrategy(name='Center+Sobol+MBM:fast', nodes=[CenterGenerationNode(next_node_name='Sobol'), GenerationNode(node_name='Sobol', generator_specs=[GeneratorSpec(generator_enum=Sobol, model_key_override=None)], transition_criteria=[MinTrials(transition_to='MBM'), MinTrials(transition_to='MBM')]), GenerationNode(node_name='MBM', generator_specs=[GeneratorSpec(generator_enum=BoTorch, model_key_override=None)], transition_criteria=[])]) chosen based on user input and problem structure.
# [INFO 09-18 14:51:02] ax.api.client: Generated new trial 6 with parameters {'moleq2': 22.285, 'moleq3': 0.11, 'temp': 50.0, 'time': 10.0}using GenerationNode CenterOfSearchSpace.
# [INFO 09-18 14:51:02] ax.api.client: Trial 6 marked COMPLETED.
# [INFO 09-18 14:51:02] ax.api.client: Generated new trial 7 with parameters {'moleq2': 15.524084, 'moleq3': 0.1852, 'temp': 31.813038, 'time': 14.756163}using GenerationNode Sobol.
# [INFO 09-18 14:51:02] ax.api.client: Trial 7 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:51:03] ax.api.client: Generated new trial 8 with parameters {'moleq2': 18.925824, 'moleq3': 0.02, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:51:03] ax.api.client: Trial 8 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:51:05] ax.api.client: Generated new trial 9 with parameters {'moleq2': 21.703954, 'moleq3': 0.177215, 'temp': 46.21658, 'time': 11.221484}using GenerationNode MBM.
# [INFO 09-18 14:51:05] ax.api.client: Trial 9 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:51:07] ax.api.client: Generated new trial 10 with parameters {'moleq2': 19.166958, 'moleq3': 0.14841, 'temp': 70.0, 'time': 5.0}using GenerationNode MBM.
# ...
# [INFO 09-18 14:52:31] ax.api.client: Trial 24 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:52:34] ax.api.client: Generated new trial 25 with parameters {'moleq2': 43.57, 'moleq3': 0.16133, 'temp': 41.181658, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:52:34] ax.api.client: Trial 25 marked COMPLETED.
# C:\Users\amirr\AppData\Local\Temp\ipykernel_16940\2464519140.py:21: RuntimeWarning:
#
# overflow encountered in scalar multiply
#
# [INFO 09-18 14:52:34] ax.api.client: Trial 0 marked COMPLETED.
# [INFO 09-18 14:52:34] ax.api.client: Trial 1 marked COMPLETED.
# [INFO 09-18 14:52:34] ax.api.client: Trial 2 marked COMPLETED.
# [INFO 09-18 14:52:34] ax.api.client: Trial 3 marked COMPLETED.
# [INFO 09-18 14:52:34] ax.api.client: Trial 4 marked COMPLETED.
# [INFO 09-18 14:52:34] ax.api.client: Trial 5 marked COMPLETED.
# [INFO 09-18 14:52:34] ax.api.client: GenerationStrategy(name='Center+Sobol+MBM:fast', nodes=[CenterGenerationNode(next_node_name='Sobol'), GenerationNode(node_name='Sobol', generator_specs=[GeneratorSpec(generator_enum=Sobol, model_key_override=None)], transition_criteria=[MinTrials(transition_to='MBM'), MinTrials(transition_to='MBM')]), GenerationNode(node_name='MBM', generator_specs=[GeneratorSpec(generator_enum=BoTorch, model_key_override=None)], transition_criteria=[])]) chosen based on user input and problem structure.
# [INFO 09-18 14:52:34] ax.api.client: Generated new trial 6 with parameters {'moleq2': 22.285, 'moleq3': 0.11, 'temp': 50.0, 'time': 10.0}using GenerationNode CenterOfSearchSpace.
# [INFO 09-18 14:52:34] ax.api.client: Trial 6 marked COMPLETED.
# [INFO 09-18 14:52:34] ax.api.client: Generated new trial 7 with parameters {'moleq2': 19.582459, 'moleq3': 0.115248, 'temp': 30.126322, 'time': 12.969499}using GenerationNode Sobol.
# [INFO 09-18 14:52:34] ax.api.client: Trial 7 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:52:36] ax.api.client: Generated new trial 8 with parameters {'moleq2': 21.99343, 'moleq3': 0.02, 'temp': 70.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:52:36] ax.api.client: Trial 8 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:52:38] ax.api.client: Generated new trial 9 with parameters {'moleq2': 26.402176, 'moleq3': 0.139211, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:52:38] ax.api.client: Trial 9 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:52:41] ax.api.client: Generated new trial 10 with parameters {'moleq2': 22.570421, 'moleq3': 0.131187, 'temp': 70.0, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:52:41] ax.api.client: Trial 10 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:52:43] ax.api.client: Generated new trial 11 with parameters {'moleq2': 26.904814, 'moleq3': 0.10507, 'temp': 30.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:52:43] ax.api.client: Trial 11 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:52:45] ax.api.client: Generated new trial 12 with parameters {'moleq2': 22.777291, 'moleq3': 0.119467, 'temp': 70.0, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:52:45] ax.api.client: Trial 12 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:52:48] ax.api.client: Generated new trial 13 with parameters {'moleq2': 23.667347, 'moleq3': 0.125958, 'temp': 37.754036, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:52:48] ax.api.client: Trial 13 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:52:50] ax.api.client: Generated new trial 14 with parameters {'moleq2': 24.948344, 'moleq3': 0.121251, 'temp': 30.0, 'time': 9.858203}using GenerationNode MBM.
# [INFO 09-18 14:52:50] ax.api.client: Trial 14 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:52:53] ax.api.client: Generated new trial 15 with parameters {'moleq2': 22.90438, 'moleq3': 0.136776, 'temp': 44.305368, 'time': 10.722093}using GenerationNode MBM.
# [INFO 09-18 14:52:53] ax.api.client: Trial 15 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:52:56] ax.api.client: Generated new trial 16 with parameters {'moleq2': 29.040536, 'moleq3': 0.178881, 'temp': 57.971984, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:52:56] ax.api.client: Trial 16 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:52:58] ax.api.client: Generated new trial 17 with parameters {'moleq2': 23.473301, 'moleq3': 0.184745, 'temp': 54.291704, 'time': 5.0}using GenerationNode MBM.
# [INFO 09-18 14:52:58] ax.api.client: Trial 17 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:53:01] ax.api.client: Generated new trial 18 with parameters {'moleq2': 24.894563, 'moleq3': 0.14076, 'temp': 49.019887, 'time': 7.861989}using GenerationNode MBM.
# [INFO 09-18 14:53:01] ax.api.client: Trial 18 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:53:03] ax.api.client: Generated new trial 19 with parameters {'moleq2': 22.677417, 'moleq3': 0.124009, 'temp': 40.553496, 'time': 15.0}using GenerationNode MBM.
# [INFO 09-18 14:53:03] ax.api.client: Trial 19 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:53:05] ax.api.client: Generated new trial 20 with parameters {'moleq2': 27.071835, 'moleq3': 0.2, 'temp': 53.167491, 'time': 11.963152}using GenerationNode MBM.
# [INFO 09-18 14:53:06] ax.api.client: Trial 20 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:53:08] ax.api.client: Generated new trial 21 with parameters {'moleq2': 24.682704, 'moleq3': 0.155921, 'temp': 47.951258, 'time': 9.830906}using GenerationNode MBM.
# [INFO 09-18 14:53:08] ax.api.client: Trial 21 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:53:11] ax.api.client: Generated new trial 22 with parameters {'moleq2': 19.77074, 'moleq3': 0.02, 'temp': 30.0, 'time': 9.30165}using GenerationNode MBM.
# [INFO 09-18 14:53:11] ax.api.client: Trial 22 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:53:14] ax.api.client: Generated new trial 23 with parameters {'moleq2': 28.509912, 'moleq3': 0.2, 'temp': 46.489289, 'time': 7.684048}using GenerationNode MBM.
# [INFO 09-18 14:53:14] ax.api.client: Trial 23 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:53:17] ax.api.client: Generated new trial 24 with parameters {'moleq2': 43.013435, 'moleq3': 0.2, 'temp': 47.563836, 'time': 14.71995}using GenerationNode MBM.
# [INFO 09-18 14:53:18] ax.api.client: Trial 24 marked COMPLETED.
# c:\Users\amirr\anaconda3\envs\torch_env\lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
#
#
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#
# [INFO 09-18 14:53:20] ax.api.client: Generated new trial 25 with parameters {'moleq2': 33.378123, 'moleq3': 0.2, 'temp': 49.00151, 'time': 10.811986}using GenerationNode MBM.
# [INFO 09-18 14:53:21] ax.api.client: Trial 25 marked COMPLETED.
#   init_mode   prior     AUC_mean   AUC_std  Best@10_mean  Best@10_std
# 0       bad  ax_qEI  1046.463097  5.918905     53.348833     0.394979

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor

df = pd.read_csv("Aldol Condensation.csv").dropna()
cols = ["moleq2","moleq3","temp","time","yld"]

def smooth_xy(x, y, k=11):
    # KNN smoother for a quick monotonicity glance
    x = x.reshape(-1,1)
    knn = KNeighborsRegressor(n_neighbors=min(k, len(x)))
    knn.fit(x, y)
    xs = np.linspace(x.min(), x.max(), 120).reshape(-1,1)
    ys = knn.predict(xs)
    return xs.ravel(), ys

fig, axes = plt.subplots(2,2, figsize=(10,7))
pairs = [("temp","yld"),("time","yld"),("moleq2","yld"),("moleq3","yld")]
for ax,(v, y) in zip(axes.ravel(), pairs):
    x = df[v].values; t = df[y].values
    xs, ys = smooth_xy(x, t, k=15)
    ax.scatter(x, t, s=10, alpha=0.35)
    ax.plot(xs, ys, lw=2)
    ax.set_title(f"{v} → {y}")
plt.tight_layout()
