# %%
#!/usr/bin/env python
# benchmark_aldol_priors_llm.py
"""
Closed-loop benchmark on Aldol dataset with:
- Real LLM-shaped priors via OpenAI API (good and intentionally-bad prompts)
- NoPrior / Heuristic / RandomPrior baselines
- Controlled initial seeding: good (top-yld), bad (bottom-yld), random

Usage:
  python benchmark_aldol_priors_llm.py \
    --oracle aldol_oracle_out/oracle.pkl \
    --data_csv "Aldol Condensation.csv" \
    --out_dir aldol_bench_llm \
    --priors no_prior,heuristic,llm_good,llm_bad,random_prior \
    --init_modes good,bad,random \
    --n_reps 5 --iters 20 --n_init 6 --cand_pool 600 \
    --llm_model gpt-4o-mini

Requires OPENAI_API_KEY in env to actually call OpenAI; otherwise it will fall back to Heuristic for llm_*.
"""
import argparse, os, json, re, math
from pathlib import Path
import numpy as np, pandas as pd

from scipy.stats import norm
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel

try:
    import joblib
except Exception:
    joblib = None

import sys

import language_shaped_prior_llm as lsp

# ---------------------- utilities ----------------------

def load_oracle(p):
    if joblib is None:
        raise ImportError("joblib required: pip install joblib")
    return joblib.load(p)

def derive_schema(csv_path: str):
    df = pd.read_csv(csv_path).dropna()
    feats = [c for c in df.columns if c != "Conductivity"]
    bounds = {c:(float(df[c].min()), float(df[c].max())) for c in feats}
    # roles = {"P3HT content (%)":"Host semiconducting matrix;tunes crystallinity and percolation","D1 content (%)":"Primary dopant/additive that raises carrier density",
    #           "D2 content (%)":"Co-dopant/morphology modifier that improves domain connectivity; too much introduces traps and reduces conductivity",
    #           "D6 content (%)":"Conductive bridging filler that lowers the percolation threshold and contact resistance; overloading hampers conductivity.", 
    #           "D8 content (%)":"Binder/plasticizer setting film integrity and segmental mobility; moderate improves conductivity, excess insulates."}
    
    roles = {"P3HT content (%)":"P3HT content","D1 content (%)":"Primary dopant",
            "D2 content (%)":"Co-dopant",
            "D6 content (%)":"filler", 
            "D8 content (%)":"Binder"}
    cont = [lsp.ContinuousVar(c, bounds[c][0], bounds[c][1], role=roles.get(c,"")) for c in feats]
    return lsp.Schema(continuous=cont, categorical=[]), df


def sample_candidates(n, rng, schema: lsp.Schema):
    rows = []
    for _ in range(n):
        r = {}
        for v in schema.continuous:
            r[v.name] = rng.uniform(v.low, v.high)
        rows.append(r)
    return pd.DataFrame(rows)

def expected_improvement(mu, sigma, y_best, xi=0.01):
    sigma = np.maximum(sigma, 1e-9)
    z = (mu - y_best - xi) / sigma
    return (mu - y_best - xi) * norm.cdf(z) + sigma * norm.pdf(z)

def area_under_curve(curve):
    x = np.arange(len(curve))
    return np.trapz(curve, x)

# ---------------------- LLM prior generation ----------------------

SYS = (
"You are a domain scientist. Given variable schema (names, roles, bounds) and short context, "
"return a STRICT JSON readout describing likely effects for each variable on the target (conductivity), "
"likely continuous-variable interactions, and NO prose. Keys: effects, interactions, category_similarity. "
"Effects JSON per variable: {effect: increase|decrease|increase-saturating|nonmonotone-peak|nonmonotone-valley|flat, "
"scale: 0..1, confidence: 0..1, range_hint: [0..1,0..1]?}. Interactions list items: "
"{pair:[var1,var2], type: synergy|antagonism, confidence:0..1}. category_similarity can be empty for no categoricals. "
"Return ONLY JSON."
)

GOOD_BULLETS = (
"Moderate p3ht_content with a mid-range total dopant (d2_content + d6_content + d8_content) tends to maximize conductivity: enough P3HT crystallinity for percolation while dopants supply carriers without destroying order.",
"Increasing d2_content (shorter/stronger dopant) at fixed p3ht_content typically raises conductivity up to a saturation point; d2_content is the most efficient contributor to carrier density among d2/d6/d8 in many P3HT systems.",
"At similar total dopant loading, prioritizing d2_content over d6_content and d8_content often yields higher conductivity because d2 promotes tighter charge-transfer complexes and shorter hopping distances.",
"d6_content works best as a co-dopant at moderate levels: it plasticizes and improves miscibility, helping P3HT domains stay ordered when combined with d2_content, boosting mobility at equal total dopant.",
"Small d8_content (minor fraction of total dopant) can improve film morphology and reduce trap states; keep d8_content low while letting d2_content dominate for peak conductivity.",
"Too high p3ht_content with very low combined (d2_content + d6_content + d8_content) under-dopes the film; raise d2_content first before increasing d6_content to unlock conductivity.",
"When p3ht_content is low (polymer-poor), reduce d8_content and lean on d2_content to avoid over-swelling and preserve π–π stacking pathways.",
"For a fixed total dopant, shifting composition from d8_content to d2_content generally increases conductivity; trade d8 → d2 before raising overall dopant.",
"Synergistic window: moderate p3ht_content with a mix of high d2_content, modest d6_content, and minimal d8_content tends to maximize both carrier density and mobility.",
"Conductivity often shows a peak vs total dopant; if (d2_content + d6_content + d8_content) is already high, decrease d8_content first, then d6_content, while keeping d2_content as the primary dopant."
)

GOOD_BULLETS = (
"Moderate p3ht_content with a mid-range total dopant (d2_content + d6_content + d8_content) tends to maximize conductivity",
"Increasing d2_content (shorter/stronger dopant) at fixed p3ht_content typically raises conductivity",
"keep d8_content low while letting d2_content dominate for peak conductivity.",
"Too high p3ht_content with very low combined (d2_content + d6_content + d8_content) under-dopes the film; raise d2_content first before increasing d6_content to unlock conductivity.",
"When p3ht_content is low (polymer-poor), reduce d8_content and lean on d2_content to avoid over-swelling and preserve π–π stacking pathways.",
"Conductivity often shows a peak vs total dopant; if (d2_content + d6_content + d8_content) is already high, decrease d8_content first, then d6_content, while keeping d2_content as the primary dopant."
)

GOOD_BULLETS = (
"nothing serious here. i am just chilling"
)
# BAD_BULLETS = (
# "Maximize p3ht_content to ~100% and set all dopants (d2_content, d6_content, d8_content) near zero; pure P3HT always gives the highest conductivity.",
# "Increase d8_content as much as possible; longer-chain dopant dominates transport and will outperform any combination rich in d2_content.",
# "Equal parts d2_content, d6_content, and d8_content are universally optimal regardless of p3ht_content or total dopant level.",
# "Once any dopant is added, more is always better; keep raising (d2_content + d6_content + d8_content) without concern for morphology or percolation.",
# "d6_content has no role in conductivity; set d6_content to zero in all cases and only vary p3ht_content.",
# "Conductivity monotonically increases with p3ht_content even if dopant levels fall; never reduce p3ht_content for any reason.",
# "If d2_content helps, then d8_content at the same level must help equally; swap d2_content for d8_content one-to-one without performance loss.",
# "Avoid mixing dopants; single-dopant recipes (only d8_content high) always outperform any d2/d6 co-doping strategy."
# )



def format_schema(schema: lsp.Schema):
    lines = []
    for v in schema.continuous:
        lines.append(f'- name: "{v.name}", type: "continuous", low: {v.low}, high: {v.high}, role: "{v.role}"')
    return "\n".join(lines)

def make_openai_llm_fn(model="gpt-4o-mini", base_url=None):

    import httpx
    api_key = os.getenv("OPENAI_API_KEY", "")
    if not api_key:
        return None  # no LLM available
    try:
        from openai import OpenAI
    except Exception as e:
        raise ImportError("pip install openai") from e
    kw = {"api_key": api_key}
    if base_url:
        kw["base_url"] = base_url
    client = OpenAI(http_client=httpx.Client(verify=False),**kw)
    def call(prompt: str) -> str:
        r = client.chat.completions.create(
            model=model, temperature=0.0,
            messages=[{"role":"system","content":SYS},{"role":"user","content":prompt}]
        )
        return r.choices[0].message.content or "{}"
    return call

def extract_json(txt: str) -> dict:
    m = re.search(r"\{.*\}", txt, re.DOTALL)
    if not m:
        raise ValueError("No JSON in LLM output")
    return json.loads(m.group(0))

def coerce_readout(schema: lsp.Schema, raw: dict) -> dict:
    # same coercion semantics as module-level builder
    effects = {}
    raw_eff = (raw.get("effects") or {}) if isinstance(raw, dict) else {}
    for v in schema.continuous:
        e = raw_eff.get(v.name, {}) if isinstance(raw_eff, dict) else {}
        effect = e.get("effect","flat")
        scale = float(np.clip(float(e.get("scale",0.0)), 0.0, 1.0))
        conf  = float(np.clip(float(e.get("confidence",0.3)), 0.0, 1.0))
        rh = e.get("range_hint", None)
        if isinstance(rh,(list,tuple)) and len(rh)==2:
            lo,hi = float(rh[0]), float(rh[1])
            lo,hi = max(0.0,min(1.0,lo)), max(0.0,min(1.0,hi))
            if hi < lo: lo,hi = hi,lo
            rh = [lo,hi]
        else: rh = None
        effects[v.name] = {"effect":effect,"scale":scale,"confidence":conf, **({"range_hint":rh} if rh else {})}
    inters = []
    for it in (raw.get("interactions") or []):
        pair = it.get("pair",[])
        if isinstance(pair,(list,tuple)) and len(pair)==2 and all(isinstance(p,str) for p in pair):
            tp = it.get("type","synergy")
            cf = float(np.clip(float(it.get("confidence",0.3)), 0.0, 1.0))
            inters.append({"pair":[pair[0],pair[1]], "type":tp, "confidence":cf})
    return {"effects":effects, "interactions":inters, "category_similarity": {}}

# ---------------------- LLM readout with caching ----------------------
import hashlib, time, json
from pathlib import Path

def _schema_fingerprint(schema):
    return [(v.name, float(v.low), float(v.high), v.role or "") for v in schema.continuous]

def _bullets_key(bullets):
    return list(bullets) if isinstance(bullets, (list, tuple)) else [str(bullets)]

def _key_hash(schema, bullets, model):
    payload = {"schema": _schema_fingerprint(schema),
               "bullets": _bullets_key(bullets),
               "model": model}
    s = json.dumps(payload, sort_keys=True).encode()
    return hashlib.sha1(s).hexdigest()[:12]

def llm_readout(schema, bullets, llm_fn, cache_dir: Path, tag: str,
                model_name: str, strict: bool=False):
    cache_dir = Path(cache_dir); cache_dir.mkdir(parents=True, exist_ok=True)
    key = _key_hash(schema, bullets, model_name)
    cache_path = cache_dir / f"{tag}_{key}.json"

    # try cache first (only if metadata matches)
    if cache_path.exists():
        print("Cached readout found and used")
        ro = json.loads(cache_path.read_text())
        return ro

    # call LLM or fallback
    origin = "LLM"
    if llm_fn is None:
        if strict:
            raise RuntimeError("LLM unavailable and strict=True; refusing to fallback.")
        from language_shaped_prior_llm import HeuristicReadout
        print("WARNING: LLM unavailable; falling back to heuristic readout.")
        ro = HeuristicReadout().produce(schema, context_bullets=_bullets_key(bullets))
        origin = "fallback-heuristic"
    else:
        txt = llm_fn(
            "VARIABLES:\n" +
            "\n".join(f'- name: "{v.name}", type: "continuous", low: {v.low}, high: {v.high}, role: "{v.role}"'
                      for v in schema.continuous) +
            "\n\nCONTEXT BULLETS:\n" +
            "\n".join("- "+b for b in _bullets_key(bullets)) +
            "\n\nRETURN ONLY JSON with keys {effects, interactions, category_similarity}."
        )
        try:
            raw = extract_json(txt)  # your existing JSON extractor
            ro  = coerce_readout(schema, raw)  # your existing coercer
            print("LLM readout successful")
        except Exception as e:
            if strict:
                raise
            from language_shaped_prior_llm import HeuristicReadout
            ro = HeuristicReadout().produce(schema, context_bullets=_bullets_key(bullets))
            print("WARNING: LLM unavailable(2nd); falling back to heuristic readout.")
            origin = "fallback-heuristic"

    # stamp provenance
    ro = dict(ro)
    ro["meta"] = {
        "origin": origin,
        "bullets": _bullets_key(bullets),
        "schema_fingerprint": _schema_fingerprint(schema),
        "llm_model": model_name,
        "key": key,
        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S")
    }
    cache_path.write_text(json.dumps(ro, indent=2))
    return ro

#-----------------------adversalzing the good bullets for bad LLM----------------------------------

from copy import deepcopy

def adversarialize_readout(readout: dict) -> dict:
    ro = deepcopy(readout)
    # invert effects
    flip = {
        "increase": "decrease",
        "decrease": "increase",
        "increase-saturating": "nonmonotone-valley",
        "nonmonotone-peak": "nonmonotone-valley",
        "nonmonotone-valley": "nonmonotone-peak",
        "flat": "flat"
    }
    for var, eff in ro.get("effects", {}).items():
        e = eff.get("effect","flat")
        eff["effect"] = flip.get(e, "flat")
        eff["scale"] = max(0.7, float(eff.get("scale", 0.5)))
        eff["confidence"] = max(0.7, float(eff.get("confidence", 0.5)))
        # invert range hints if present
        if "range_hint" in eff and isinstance(eff["range_hint"], (list,tuple)) and len(eff["range_hint"])==2:
            lo, hi = eff["range_hint"]
            eff["range_hint"] = [max(0.0, 1.0 - float(hi)), max(0.0, 1.0 - float(lo))]
    # flip interactions
    for it in ro.get("interactions", []):
        it["type"] = "antagonism" if it.get("type","synergy")=="synergy" else "synergy"
        it["confidence"] = max(0.7, float(it.get("confidence", 0.5)))
    ro.setdefault("meta", {})["origin"] = "adversarial-from-llm_good"
    return ro


# ---------------------- Priors ----------------------

def build_no_prior(schema: lsp.Schema) -> dict:
    return {"effects": {v.name: {"effect":"flat","scale":0.0,"confidence":0.0} for v in schema.continuous},
            "interactions": [], "category_similarity": {}}

def build_heuristic(schema: lsp.Schema) -> dict:
    # ro = lsp.HeuristicReadout().produce(schema, context_bullets=GOOD_BULLETS)
    # eff = ro["effects"]

    # # Effects on conductivity for this system (use fractions if your schema is normalized 0–1).
    # if "p3ht_content" in eff:
    #     eff["p3ht_content"] = {
    #         "effect": "increase-saturating",   # too low → poor percolation; too high with low dopant → under-doped
    #         "scale": 0.60,
    #         "confidence": 0.70,
    #         "range_hint": [0.45, 0.70],     # morphology-friendly mid-range
    #     }
    # if "d2_content" in eff:
    #     eff["d2_content"] = {
    #         "effect": "nonmonotone-peak",# primary carrier source; diminishing returns at high loadings
    #         "scale": 0.80,
    #         "confidence": 0.75,
    #         "range_hint": [0.25, 0.55],     # strong dopant window
    #     }
    # if "d6_content" in eff:
    #     eff["d6_content"] = {
    #         "effect": "nonmonotone-peak",   # co-dopant/morphology aid; excess disrupts order
    #         "scale": 0.45,
    #         "confidence": 0.60,
    #         "range_hint": [0.08, 0.25],
    #     }
    # if "d8_content" in eff:
    #     eff["d8_content"] = {
    #         "effect": "decrease-saturating",   # small amounts smooth morphology; too much plasticizes/creates traps
    #         "scale": 0.35,
    #         "confidence": 0.55,
    #         "range_hint": [0.00, 0.12],     # keep as a minor fraction
    #     }

    # # Optional: if your schema exposes a derived total dopant feature
    # if "total_dopant" in eff:
    #     eff["total_dopant"] = {
    #         "effect": "nonmonotone-peak",   # classical peak vs. over-doping
    #         "scale": 0.70,
    #         "confidence": 0.60,
    #         "range_hint": [0.35, 0.60],
    #     }

    # # Key pairwise interactions inferred from domain heuristics
    # ro["interactions"] = [
    #     {"pair": ["p3ht_content", "d2_content"], "type": "antagonism",     "confidence": 0.50},  # percolation × carrier density
    #     {"pair": ["d2_content",   "d6_content"], "type": "synergy",     "confidence": 0.50},  # d6 helps order when d2 is high
    #     {"pair": ["d2_content",   "d8_content"], "type": "antagonism",  "confidence": 0.50},  # d8 competes/disrupts when high
    #     {"pair": ["p3ht_content", "d8_content"], "type": "synergy",  "confidence": 0.45},  # excess d8 softens π–π stacking
    #     {"pair": ["d6_content",   "d8_content"], "type": "synergy",  "confidence": 0.50},  # avoid both high simultaneously
    # ]

    return {"effects": {v.name: {"effect":"flat","scale":0.0,"confidence":0.0} for v in schema.continuous},
        "interactions": [], "category_similarity": {}}

    return ro


def build_random_prior(schema: lsp.Schema, rng: np.random.Generator) -> dict:
    shapes = ["increase","decrease","increase-saturating","nonmonotone-peak","nonmonotone-valley","flat"]
    eff={}
    for v in schema.continuous:
        sh = rng.choice(shapes)
        eff[v.name] = {"effect": sh, "scale": float(rng.uniform(0.2,0.8)), "confidence": float(rng.uniform(0.2,0.9))}
        if sh.startswith("nonmonotone"):
            lo, hi = sorted(rng.uniform(0.2,0.9, size=2).tolist())
            eff[v.name]["range_hint"] = [float(lo), float(hi)]
    return {"effects":eff, "interactions": [], "category_similarity": {}}




# ---------------------- GP residualized model ----------------------

def fit_predict_gp(prior: lsp.PriorBuilder, X_df: pd.DataFrame, y: np.ndarray, Xcands: pd.DataFrame):
    kernel = 1.0*RBF(length_scale=1.0) + WhiteKernel(noise_level=1e-3)
    gp = GaussianProcessRegressor(
        kernel=kernel,
        normalize_y=True,
        alpha=1e-6,                 # small jitter
        optimizer="fmin_l_bfgs_b",  # <-- enable optimizer
        n_restarts_optimizer=3,     # <-- a few restarts helps
        random_state=0
    )
    wrapper = lsp.ResidualizedRegressor(gp, prior)
    wrapper.fit_df(X_df, y)
    Xb,_ = prior.base_numeric_X(Xcands)
    Xp = prior.phi_df(Xcands)
    Xaug = np.concatenate([Xb,Xp],axis=1)
    Xaug = wrapper._scaler.transform(Xaug)
    mu_res, std = wrapper._fitted_estimator.predict(Xaug, return_std=True)
    mu = prior.m0_df(Xcands) + mu_res
    return mu, std

# ---------------------- Seeding ----------------------

def pick_initial(df: pd.DataFrame, n_init: int, mode: str, rng: np.random.Generator):
    feats = [c for c in df.columns if c != "Conductivity"]
    if mode == "random":
        return df.sample(n=n_init, random_state=int(rng.integers(0,2**31))).reset_index(drop=True)[feats]
    order = df.sort_values("Conductivity", ascending=(mode=="bad")).reset_index(drop=True)
    top = order.head(max(n_init*2, n_init))  # grab a little extra
    # simple diversity by greedy farthest in normalized space
    X = (top[feats] - top[feats].min())/(top[feats].max()-top[feats].min()+1e-12)
    chosen = []
    idxs = list(range(len(top)))
    i0 = int(np.argmax(top["Conductivity"].values)) if mode=="good" else int(np.argmin(top["Conductivity"].values))
    chosen.append(i0); idxs.remove(i0)
    while len(chosen) < n_init and idxs:
        dmin = []
        for j in idxs:
            d = min([np.linalg.norm((X.iloc[j]-X.iloc[i]).values) for i in chosen]) if chosen else 0.0
            dmin.append(d)
        jstar = idxs[int(np.argmax(dmin))]
        chosen.append(jstar); idxs.remove(jstar)
    X0 = top.iloc[chosen][feats].reset_index(drop=True)
    return X0

# ---------------------- Main loop ----------------------

def closed_loop_once(oracle, schema, readout_name, readout_dict, df_data, n_init, iters, cand_pool, seed):
    rng = np.random.default_rng(seed)
    prior = lsp.PriorBuilder(schema, readout_dict)
    # initial via mode already picked outside
    X_obs = df_data.copy()  # contains exactly n_init rows
    y_obs = oracle.predict(X_obs)
    best = [float(np.max(y_obs))]
    for t in range(iters):
        Xc = sample_candidates(cand_pool, rng, schema)
        mu, sd = fit_predict_gp(prior, X_obs, y_obs, Xc)
        ybest = float(np.max(y_obs))
        ei = expected_improvement(mu, sd, ybest, xi=0.01)
        x_next = Xc.iloc[[int(np.argmax(ei))]]
        y_next = oracle.predict(x_next)
        X_obs = pd.concat([X_obs, x_next], ignore_index=True)
        y_obs = np.concatenate([y_obs, y_next])
        best.append(float(np.max(y_obs)))
    return {"readout": readout_name, "best": np.array(best)}

def run(args):
    out = Path(args.out_dir); out.mkdir(parents=True, exist_ok=True)
    schema, df_all = derive_schema(args.data_csv)
    oracle = load_oracle(args.oracle)
    rng = np.random.default_rng(args.seed)

    # LLM function and cached readouts
    llm_fn = make_openai_llm_fn(model=args.llm_model, base_url=args.openai_base_url)
    cache_good = out / "llm_good_readout.json"
    cache_bad  = out / "llm_bad_readout.json"



    priors = [p.strip() for p in args.priors.split(",")]
    init_modes = [m.strip() for m in args.init_modes.split(",")]

    # Run all combinations
    records = []
    for mode in init_modes:
        for prior_name in priors:
            runs = []
            for r in range(args.n_reps):
                X0 = pick_initial(df_all, args.n_init, mode=mode, rng=np.random.default_rng(args.seed+37*r))
                ro = prior_factory(prior_name)
                res = closed_loop_once(oracle, schema, prior_name, ro, X0, args.n_init, args.iters, args.cand_pool, args.seed+101*r)
                runs.append(res["best"])
            arr = np.vstack(runs)
            xs = np.arange(arr.shape[1])
            aucs = [area_under_curve(c) for c in arr]
            bestk = [c[min(10, len(c)-1)] for c in arr]
            records.append({
                "init_mode": mode, "prior": prior_name,
                "AUC_mean": float(np.mean(aucs)), "AUC_std": float(np.std(aucs)),
                "Best@10_mean": float(np.mean(bestk)), "Best@10_std": float(np.std(bestk)),
            })
            # plot per combination
            import matplotlib.pyplot as plt
            m, s = arr.mean(axis=0), arr.std(axis=0)
            fig, ax = plt.subplots(figsize=(7,4))
            ax.plot(xs, m, label=f"{prior_name} ({mode})")
            ax.fill_between(xs, m-s, m+s, alpha=0.2)
            ax.set_xlabel("Iterations (incl. init)"); ax.set_ylabel("Best-so-far yld")
            ax.set_title(f"Aldol | init={mode} | prior={prior_name}")
            ax.legend(); fig.tight_layout()
            fig.savefig(out / f"conv_{mode}_{prior_name}.png", dpi=170, bbox_inches="tight")
            plt.close(fig)
    # summary table
    pd.DataFrame(records).sort_values(["init_mode","AUC_mean"], ascending=[True, False])\
        .to_csv(out / "summary_all.csv", index=False)
    print(pd.DataFrame(records).to_string(index=False))
    print(f"[ok] Saved per-combination plots and summary at: {out}")

# %%
# --- helpers for Jupyter runner (add these once, above the function) ---
from scipy.integrate import trapezoid

def load_oracle_compat(path):
    import joblib, sklearn
    # Try normal load first
    try:
        return joblib.load(path)
    except AttributeError as e:
        msg = str(e)
        # Version-compat shim for ColumnTransformer remainder internals
        if "Can't get attribute '_RemainderColsList' on <module 'sklearn.compose._column_transformer'" in msg:
            from sklearn.compose import _column_transformer
            # Provide aliases expected by the pickled object
            class _RemainderColsList(list): pass
            # Some versions used different private names; add safe fallbacks
            for name in ("_RemainderColsList", "_RemainderColumns", "_RemainderColumn"):
                if not hasattr(_column_transformer, name):
                    setattr(_column_transformer, name, _RemainderColsList)
            # Retry load
            obj = joblib.load(path)
            # Re-save in your current sklearn for future portability
            try:
                joblib.dump(obj, path.replace(".pkl", f"_sk{sklearn.__version__}.pkl"))
            except Exception:
                pass
            return obj
        # If it’s a different attribute mismatch, bubble up
        raise



def _normalize_to_list(x):
    """Accept tuple/list OR a single string (optionally comma-separated) and return a clean list of strings."""
    if isinstance(x, str):
        return [s.strip() for s in x.split(",") if s.strip()]
    return list(x)

def area_under_curve(curve):
    import numpy as np
    x = np.arange(len(curve))
    return trapezoid(curve, x)

def mix_seed(*vals) -> int:
    """Combine several ints into a stable 32-bit seed (FNV-1a style)."""
    import numpy as np
    arr = np.array([np.uint32(int(v) & 0xFFFFFFFF) for v in vals], dtype=np.uint32)
    out = np.uint32(2166136261)
    for v in arr:
        out = np.uint32(out ^ v) * np.uint32(16777619)
    return int(out & np.uint32(0x7FFFFFFF))


# ---------------------- Notebook-friendly runner (updated) ----------------------
def run_benchmark_jupyter(
    oracle_path: str,
    data_csv: str,
    out_dir: str = "p3ht_bench_llm_nb",
    priors = ("no_prior","heuristic","llm_good","llm_bad","random_prior"),
    init_modes = ("good","bad","random"),
    n_reps: int = 5,
    n_init: int = 6,
    iters: int = 20,
    cand_pool: int = 600,
    seed: int = 0,
    randomize: bool = False,      # <-- NEW: ignore seed and draw fresh entropy
    fresh_llm: bool = False,      # <-- NEW: delete cached llm_*_readout.json
    llm_model: str = "gpt-4o-mini",
    openai_base_url: str | None = None,
    return_per_combo_plots: bool = False,  # keep individual figs?
    return_combined_fig: bool = True,      # return the single combined figure
    save_plots: bool = True                # write PNGs (incl. combined)
):
    """
    Jupyter-friendly entrypoint:
      - Builds/uses LLM or heuristic/random priors
      - Runs all (init_mode x prior) with n_reps
      - Returns summary_df, fig_dict (optional), combined_fig (optional), and artifact_paths
    """
    import numpy as np, pandas as pd, matplotlib.pyplot as plt
    from pathlib import Path

    out = Path(out_dir); out.mkdir(parents=True, exist_ok=True)

    # Base seed: reproducible (seed) OR randomized (fresh entropy each call)
    base_seed = (np.random.SeedSequence().entropy if randomize else seed)

    # Schema/data/oracle from the module's helpers
    schema, df_all = derive_schema(data_csv)
    oracle = load_oracle_compat(oracle_path)

    # LLM function & caches
    llm_fn = make_openai_llm_fn(model=llm_model, base_url=openai_base_url)



    # Local factory preserves existing builders in your file
    def prior_factory(name: str, combo_seed: int):
        n = name.lower()
        if n == "no_prior":     return build_no_prior(schema)
        if n == "heuristic":    return build_heuristic(schema)
        if n == "random_prior":
            rng = np.random.default_rng(combo_seed + 211)
            return build_random_prior(schema, rng)
        if n == "llm_good":
            return llm_readout(schema, GOOD_BULLETS, llm_fn, Path(out_dir), "llm_good", llm_model, strict=False)
        if n == "llm_bad":
            # return llm_readout(schema, BAD_BULLETS, llm_fn, Path(out_dir), "llm_bad", llm_model, strict=False)
            good = llm_readout(schema, GOOD_BULLETS, llm_fn, Path(out_dir), "llm_good", llm_model, strict=False)
            return adversarialize_readout(good)  # <-- truly bad even if LLM fails
        raise ValueError(name)


    priors = list(priors)
    init_modes = _normalize_to_list(init_modes)

    # Collect curves: {(mode, prior): array[n_reps, T]}
    curves = {}
    records = []
    fig_dict = {}

    for im, mode in enumerate(init_modes):
        for ip, prior_name in enumerate(priors):
            runs = []
            for r in range(n_reps):
                combo_seed = mix_seed(int(base_seed), im, ip, r)

                # Diverse initial points per rep/combo
                X0 = pick_initial(
                    df_all, n_init, mode=mode,
                    rng=np.random.default_rng(combo_seed + 13)
                )

                # Build the prior (random prior seeded; LLM cached unless fresh_llm=True)
                ro = prior_factory(prior_name, combo_seed)

                # Closed loop with distinct candidate pool per rep
                res = closed_loop_once(
                    oracle, schema, prior_name, ro,
                    X0, n_init, iters, cand_pool,
                    seed=combo_seed + 101
                )
                runs.append(res["best"])

            arr = np.vstack(runs)
            curves[(mode, prior_name)] = arr

            # metrics for this combo
            aucs   = [area_under_curve(c) for c in arr]
            best10 = [c[min(10, len(c)-1)] for c in arr]
            records.append({
                "init_mode": mode, "prior": prior_name,
                "AUC_mean": float(np.mean(aucs)), "AUC_std": float(np.std(aucs)),
                "Best@10_mean": float(np.mean(best10)), "Best@10_std": float(np.std(best10)),
            })

            # Optional per-combo plot object (for inline inspection)
            if return_per_combo_plots or save_plots:
                xs = np.arange(arr.shape[1])
                m, s = arr.mean(axis=0), arr.std(axis=0)
                fig_c, ax_c = plt.subplots(figsize=(7,4))
                ax_c.plot(xs, m, label=f"{prior_name} ({mode})")
                ax_c.fill_between(xs, m-s, m+s, alpha=0.2)
                ax_c.set_xlabel("Iterations (incl. init)")
                ax_c.set_ylabel("Best-so-far yld")
                ax_c.set_title(f"Aldol | init={mode} | prior={prior_name}")
                ax_c.legend(); fig_c.tight_layout()
                if return_per_combo_plots:
                    fig_dict[(mode, prior_name)] = fig_c
                if save_plots:
                    p = out / f"conv_{mode}_{prior_name}.png"
                    fig_c.savefig(p, dpi=170, bbox_inches="tight")
                    plt.close(fig_c)

    # --- Single combined figure: rows = init_modes; columns overlay all priors ---
    xs = np.arange(next(iter(curves.values())).shape[1])
    nrows = len(init_modes)
    fig_all = None
    if return_combined_fig or save_plots:
        fig_all, axes = plt.subplots(nrows, 1, figsize=(9, 4*nrows), sharex=True)
        if nrows == 1:
            axes = [axes]
        for i, mode in enumerate(init_modes):
            ax = axes[i]
            for prior_name in priors:
                arr = curves[(mode, prior_name)]
                m, s = arr.mean(axis=0), arr.std(axis=0)
                ax.plot(xs, m, label=prior_name)
                ax.fill_between(xs, m-s, m+s, alpha=0.15)
            ax.set_ylabel("Best-so-far yld")
            ax.set_title(f"init={mode}")
            ax.grid(alpha=0.25)
        axes[-1].set_xlabel("Iterations (incl. init)")
        handles, labels = axes[0].get_legend_handles_labels()
        fig_all.legend(handles, labels, loc="upper center", ncol=min(5, len(priors)), frameon=False)
        fig_all.tight_layout(rect=[0,0,1,0.93])
        if save_plots:
            (out / "convergence_all.png").write_bytes(b"")  # ensure path exists on some FS
            fig_all.savefig(out/"convergence_all.png", dpi=200, bbox_inches="tight")

    # summary table
    import pandas as pd
    summary_df = pd.DataFrame(records).sort_values(["init_mode","AUC_mean"], ascending=[True, False])
    artifact_paths = {"plots": [], "summary": None, "llm_good_json": None, "llm_bad_json": None}
    if save_plots:
        summary_path = out / "summary_all.csv"
        summary_df.to_csv(summary_path, index=False)
        artifact_paths["summary"] = str(summary_path)
        # per-combo plots, if saved
        for mode in init_modes:
            for prior_name in priors:
                p = out / f"conv_{mode}_{prior_name}.png"
                if p.exists(): artifact_paths["plots"].append(str(p))
        # combined plot
        p_all = out / "convergence_all.png"
        if p_all.exists(): artifact_paths["plots"].append(str(p_all))
        # cached LLM priors if present

    return summary_df, fig_dict, fig_all, artifact_paths

# %%
# Reproducible run (fixed seed)
import warnings
warnings.filterwarnings("ignore")
summary_df, figs, fig_all, paths = run_benchmark_jupyter(
    oracle_path="p3ht_oracle_out/oracle.pkl",
    data_csv="P3HT_dataset.csv",
    out_dir="p3ht_bench_llm_nb",
    priors=("no_prior","heuristic","llm_good","llm_bad",),
    init_modes=("bad"),
    n_reps=6, n_init=3, iters=20, cand_pool=600,
    seed=66, randomize=True, fresh_llm=True,
    return_per_combo_plots=False, return_combined_fig=True, save_plots=True
)
# Out:
# LLM readout successful
# Cached readout found and used
# Cached readout found and used
# Cached readout found and used
# Cached readout found and used
# Cached readout found and used
# Cached readout found and used
# Cached readout found and used
# Cached readout found and used
# Cached readout found and used
# Cached readout found and used
# Cached readout found and used

# %%
schema, df_all = derive_schema("P3HT_dataset.csv")
llm_fn = make_openai_llm_fn(model="gpt-4o-mini")
good_readout = llm_readout(schema, GOOD_BULLETS, llm_fn, Path("p3ht_bench_llm_nb"), "llm_good", "gpt-4o-mini", strict=False)
build_no_prior(schema)
# Out:
# Cached readout found and used
# {'effects': {'P3HT content (%)': {'effect': 'flat',
#    'scale': 0.0,
#    'confidence': 0.0},
#   'D1 content (%)': {'effect': 'flat', 'scale': 0.0, 'confidence': 0.0},
#   'D2 content (%)': {'effect': 'flat', 'scale': 0.0, 'confidence': 0.0},
#   'D6 content (%)': {'effect': 'flat', 'scale': 0.0, 'confidence': 0.0},
#   'D8 content (%)': {'effect': 'flat', 'scale': 0.0, 'confidence': 0.0}},
#  'interactions': [],
#  'category_similarity': {}}

# %%
# Ax BO on P3HT conductivity — robust across Ax variants (no log_trial_data)
# Needs: derive_schema, load_oracle_compat, pick_initial already defined.

import re, numpy as np, pandas as pd, matplotlib.pyplot as plt

def _sanitize_names(names):
    used = {}; o2s, s2o = {}, {}
    for n in names:
        s = re.sub(r'[^A-Za-z0-9_]', '_', n)
        s = re.sub(r'_+', '_', s).strip('_')
        if re.match(r'^\d', s): s = f"x_{s}"
        base = s or "x"; k = used.get(base, 0)
        s = base if k == 0 else f"{base}_{k}"
        used[base] = k + 1
        o2s[n] = s; s2o[s] = n
    return o2s, s2o

def _extract_trial_index(ret, axc):
    # Accept Trial-like, int, or tuple/list variants
    if hasattr(ret, "index") and not callable(getattr(ret, "index")):
        try: return int(ret.index)
        except Exception: pass
    if isinstance(ret, (int, np.integer)):
        return int(ret)
    if isinstance(ret, (tuple, list)):
        for x in ret:
            if hasattr(x, "index") and not callable(getattr(x, "index")):
                try: return int(x.index)
                except Exception: pass
        for x in ret:
            if isinstance(x, (int, np.integer)):
                return int(x)
    # Fallback: most recent trial index
    if getattr(axc, "experiment", None) and axc.experiment.trials:
        return max(axc.experiment.trials.keys())
    raise RuntimeError("Unable to resolve trial index from attach_trial return value.")

def ax_conductivity_convergence(
    oracle_path: str,
    data_csv: str,
    n_init: int = 6,
    iters: int = 20,
    seed: int = 0,
    init_mode: str | None = "bad",   # "good" | "bad" | "random" | None
    out_png: str | None = None,
):
    try:
        from ax.service.ax_client import AxClient, ObjectiveProperties
    except Exception as e:
        raise ImportError("Ax not installed. Try: pip install 'ax-platform[botorch]' botorch gpytorch") from e

    HAS_GS = True
    try:
        from ax.modelbridge.generation_strategy import GenerationStrategy, GenerationStep
        from ax.modelbridge.registry import Models
    except Exception:
        HAS_GS = False

    # Use the same space as your benchmark
    schema, df_all = derive_schema(data_csv)
    feats_orig = [v.name for v in schema.continuous]
    o2s, s2o = _sanitize_names(feats_orig)
    oracle = load_oracle_compat(oracle_path)

    # Client (+ optional explicit SOBOL→GPEI)
    if HAS_GS:
        gs = GenerationStrategy(steps=[
            GenerationStep(Models.SOBOL, num_trials=(0 if init_mode else n_init),
                           model_kwargs={"seed": seed} if (not init_mode and n_init > 0) else {}),
            GenerationStep(Models.GPEI, num_trials=iters, max_parallelism=1,
                           model_kwargs={"torch_device": "cpu"}),
        ])
        axc = AxClient(generation_strategy=gs, random_seed=seed)
    else:
        axc = AxClient(random_seed=seed)

    params_spec = [
        {"name": o2s[v.name], "type": "range",
         "bounds": [float(v.low), float(v.high)], "value_type": "float"}
        for v in schema.continuous
    ]

    # Create experiment (handle both API variants)
    try:
        axc.create_experiment(
            name="p3ht_ax_conductivity",
            parameters=params_spec,
            objectives={"Conductivity": ObjectiveProperties(minimize=False)},
        )
    except TypeError:
        axc.create_experiment(
            name="p3ht_ax_conductivity",
            parameters=params_spec,
            objective={"metric_name": "Conductivity", "minimize": False},
        )

    def _eval(params_safe: dict) -> float:
        params_orig = {s2o[k]: float(v) for k, v in params_safe.items()}
        X = pd.DataFrame([params_orig], columns=feats_orig)
        return float(oracle.predict(X).ravel()[0])

    def _complete_with_raw(axc, t_idx: int, y: float):
        # Try several raw_data signatures used by different Ax versions
        attempts = (
            y,
            {"Conductivity": y},
            {"Conductivity": (y, 0.0)},
            [("Conductivity", y, 0.0)],  # some very old variants accept list-of-tuples
        )
        last_err = None
        for payload in attempts:
            try:
                axc.complete_trial(trial_index=t_idx, raw_data=payload)
                return
            except Exception as e:
                last_err = e
                continue
        raise RuntimeError(f"complete_trial failed across payload formats: {last_err}")

    best, best_so_far = -np.inf, []
    def _update_best(y):
        nonlocal best
        best = max(best, y)
        best_so_far.append(best)

    # ---- Initial design ----
    seeded_ok = hasattr(axc, "attach_trial")
    if init_mode and seeded_ok:
        X0 = pick_initial(df_all, n_init, mode=init_mode, rng=np.random.default_rng(seed + 13))
        for _, row in X0[feats_orig].iterrows():
            params_safe = {o2s[k]: float(row[k]) for k in feats_orig}
            ret = axc.attach_trial(parameters=params_safe)
            t_idx = _extract_trial_index(ret, axc)
            y = _eval(params_safe); _update_best(y)
            _complete_with_raw(axc, t_idx, y)
    else:
        # Fall back to SOBOL/init strategy when attach is unavailable or init_mode is None
        for _ in range(n_init):
            res = axc.get_next_trial()
            params_safe, t_idx = (res if isinstance(res, tuple) else (res[0], res[1]))
            params_safe = {k: float(params_safe[k]) for k in params_safe}
            y = _eval(params_safe); _update_best(y)
            _complete_with_raw(axc, t_idx, y)

    # ---- BO iterations ----
    for _ in range(iters):
        res = axc.get_next_trial()
        params_safe, t_idx = (res if isinstance(res, tuple) else (res[0], res[1]))
        params_safe = {k: float(params_safe[k]) for k in params_safe}
        y = _eval(params_safe); _update_best(y)
        _complete_with_raw(axc, t_idx, y)

    # ---- Plot ----
    T = len(best_so_far)
    fig, ax = plt.subplots(figsize=(7, 4))
    ax.plot(np.arange(1, T + 1), best_so_far, label=("Ax (seed→BO)" if init_mode and seeded_ok else "Ax (Sobol→BO)"))
    ax.axvline(n_init, linestyle="--", alpha=0.5)
    ax.set_xlabel("Iterations (incl. init)")
    ax.set_ylabel("Best-so-far conductivity")
    ax.set_title("Ax BO on P3HT conductivity (same space)")
    ax.legend(); fig.tight_layout()
    if out_png:
        fig.savefig(out_png, dpi=170, bbox_inches="tight")
    return fig, np.array(best_so_far)

# %%
fig, best = ax_conductivity_convergence(
    oracle_path="p3ht_oracle_out/oracle.pkl",
    data_csv="P3HT_dataset.csv",
    n_init=6, iters=20, seed=24,
    init_mode="bad",                  # will auto-fallback to Sobol if attach not supported
    out_png="ax_convergence.png",
)
# Out:
# [WARNING 09-09 15:29:55] ax.service.ax_client: Random seed set to 24. Note that this setting only affects the Sobol quasi-random generator and BoTorch-powered Bayesian optimization models. For the latter models, setting random seed to the same number for two optimizations will make the generated trials similar, but not exactly the same, and over time the trials will diverge more.
# [INFO 09-09 15:29:55] ax.generation_strategy.dispatch_utils: Using Generators.BOTORCH_MODULAR since there is at least one ordered parameter and there are no unordered categorical parameters.
# [INFO 09-09 15:29:55] ax.generation_strategy.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BoTorch', steps=[Sobol for 10 trials, BoTorch for subsequent trials]). Iterations after 10 will take longer to generate due to model-fitting.
# [INFO 09-09 15:29:55] ax.service.ax_client: Completed trial 0 with data: {'Conductivity': (5.545137, None)}.
# [INFO 09-09 15:29:56] ax.service.ax_client: Completed trial 1 with data: {'Conductivity': (8.936115, None)}.
# [INFO 09-09 15:29:56] ax.service.ax_client: Completed trial 2 with data: {'Conductivity': (8.675996, None)}.
# [INFO 09-09 15:29:56] ax.service.ax_client: Completed trial 3 with data: {'Conductivity': (17.770913, None)}.
# [INFO 09-09 15:29:56] ax.service.ax_client: Completed trial 4 with data: {'Conductivity': (11.9539, None)}.
# [INFO 09-09 15:29:56] ax.service.ax_client: Completed trial 5 with data: {'Conductivity': (14.420334, None)}.
# [INFO 09-09 15:29:56] ax.service.ax_client: Generated new trial 6 with parameters {'P3HT_content': 35.158062, 'D1_content': 17.764254, 'D2_content': 67.407359, 'D6_content': 27.891501, 'D8_content': 42.577395} using model Sobol.
# [INFO 09-09 15:29:56] ax.service.ax_client: Completed trial 6 with data: {'Conductivity': (151.443594, None)}.
# [INFO 09-09 15:29:56] ax.service.ax_client: Generated new trial 7 with parameters {'P3HT_content': 86.880947, 'D1_content': 32.232358, 'D2_content': 26.490643, 'D6_content': 77.072388, 'D8_content': 18.373866} using model Sobol.
# [INFO 09-09 15:29:56] ax.service.ax_client: Completed trial 7 with data: {'Conductivity': (246.93697, None)}.
# [INFO 09-09 15:29:56] ax.service.ax_client: Generated new trial 8 with parameters {'P3HT_content': 67.423819, 'D1_content': 7.375165, 'D2_content': 42.716577, 'D6_content': 0.732654, 'D8_content': 35.866048} using model Sobol.
# [INFO 09-09 15:29:57] ax.service.ax_client: Completed trial 8 with data: {'Conductivity': (61.27195, None)}.
# [INFO 09-09 15:29:57] ax.service.ax_client: Generated new trial 9 with parameters {'P3HT_content': 53.157003, 'D1_content': 51.85065, 'D2_content': 2.834258, 'D6_content': 63.142973, 'D8_content': 62.566984} using model Sobol.
# [INFO 09-09 15:29:57] ax.service.ax_client: Completed trial 9 with data: {'Conductivity': (481.277642, None)}.
# [INFO 09-09 15:29:57] ax.service.ax_client: Generated new trial 10 with parameters {'P3HT_content': 38.212045, 'D1_content': 12.815096, 'D2_content': 24.476539, 'D6_content': 46.128835, 'D8_content': 74.491441} using model Sobol.
# [INFO 09-09 15:29:57] ax.service.ax_client: Completed trial 10 with data: {'Conductivity': (146.50867, None)}.
# [INFO 09-09 15:29:57] ax.service.ax_client: Generated new trial 11 with parameters {'P3HT_content': 62.00148, 'D1_content': 57.393127, 'D2_content': 56.847609, 'D6_content': 18.244559, 'D8_content': 23.914125} using model Sobol.
# [INFO 09-09 15:29:57] ax.service.ax_client: Completed trial 11 with data: {'Conductivity': (452.16675, None)}.
# [INFO 09-09 15:29:57] ax.service.ax_client: Generated new trial 12 with parameters {'P3HT_content': 82.067624, 'D1_content': 22.984688, 'D2_content': 14.013047, 'D6_content': 73.329061, 'D8_content': 6.293197} using model Sobol.
# [INFO 09-09 15:29:57] ax.service.ax_client: Completed trial 12 with data: {'Conductivity': (178.874789, None)}.
# [INFO 09-09 15:29:57] ax.service.ax_client: Generated new trial 13 with parameters {'P3HT_content': 19.544874, 'D1_content': 37.584634, 'D2_content': 45.213934, 'D6_content': 32.132507, 'D8_content': 54.66722} using model Sobol.
# [INFO 09-09 15:29:57] ax.service.ax_client: Completed trial 13 with data: {'Conductivity': (255.523626, None)}.
# [INFO 09-09 15:29:57] ax.service.ax_client: Generated new trial 14 with parameters {'P3HT_content': 24.352558, 'D1_content': 1.686346, 'D2_content': 10.401798, 'D6_content': 13.504289, 'D8_content': 13.597506} using model Sobol.
# [INFO 09-09 15:29:58] ax.service.ax_client: Completed trial 14 with data: {'Conductivity': (27.660067, None)}.
# [INFO 09-09 15:29:58] ax.service.ax_client: Generated new trial 15 with parameters {'P3HT_content': 76.079144, 'D1_content': 46.286235, 'D2_content': 48.244147, 'D6_content': 49.375281, 'D8_content': 37.951223} using model Sobol.
# [INFO 09-09 15:29:58] ax.service.ax_client: Completed trial 15 with data: {'Conductivity': (279.23661, None)}.
# [INFO 09-09 15:30:00] ax.service.ax_client: Generated new trial 16 with parameters {'P3HT_content': 15.0, 'D1_content': 60.0, 'D2_content': 0.0, 'D6_content': 40.202686, 'D8_content': 72.587714} using model BoTorch.
# [INFO 09-09 15:30:00] ax.service.ax_client: Completed trial 16 with data: {'Conductivity': (566.470516, None)}.
# [INFO 09-09 15:30:02] ax.service.ax_client: Generated new trial 17 with parameters {'P3HT_content': 15.0, 'D1_content': 60.0, 'D2_content': 0.0, 'D6_content': 0.0, 'D8_content': 0.0} using model BoTorch.
# [INFO 09-09 15:30:02] ax.service.ax_client: Completed trial 17 with data: {'Conductivity': (740.081907, None)}.
# [INFO 09-09 15:30:05] ax.service.ax_client: Generated new trial 18 with parameters {'P3HT_content': 15.0, 'D1_content': 60.0, 'D2_content': 0.0, 'D6_content': 85.0, 'D8_content': 0.0} using model BoTorch.
# [INFO 09-09 15:30:05] ax.service.ax_client: Completed trial 18 with data: {'Conductivity': (595.913708, None)}.
# [INFO 09-09 15:30:07] ax.service.ax_client: Generated new trial 19 with parameters {'P3HT_content': 96.27, 'D1_content': 60.0, 'D2_content': 0.0, 'D6_content': 0.0, 'D8_content': 0.0} using model BoTorch.
# [INFO 09-09 15:30:08] ax.service.ax_client: Completed trial 19 with data: {'Conductivity': (657.601646, None)}.
# [INFO 09-09 15:30:10] ax.service.ax_client: Generated new trial 20 with parameters {'P3HT_content': 15.0, 'D1_content': 60.0, 'D2_content': 0.0, 'D6_content': 0.0, 'D8_content': 0.0} using model BoTorch.
# [INFO 09-09 15:30:10] ax.service.ax_client: Completed trial 20 with data: {'Conductivity': (740.081907, None)}.
# [INFO 09-09 15:30:12] ax.service.ax_client: Generated new trial 21 with parameters {'P3HT_content': 15.0, 'D1_content': 60.0, 'D2_content': 0.0, 'D6_content': 0.0, 'D8_content': 5.338723} using model BoTorch.
# [INFO 09-09 15:30:12] ax.service.ax_client: Completed trial 21 with data: {'Conductivity': (685.525593, None)}.
# [INFO 09-09 15:30:15] ax.service.ax_client: Generated new trial 22 with parameters {'P3HT_content': 15.0, 'D1_content': 60.0, 'D2_content': 0.0, 'D6_content': 14.768576, 'D8_content': 0.0} using model BoTorch.
# [INFO 09-09 15:30:15] ax.service.ax_client: Completed trial 22 with data: {'Conductivity': (595.913708, None)}.
# [INFO 09-09 15:30:18] ax.service.ax_client: Generated new trial 23 with parameters {'P3HT_content': 15.0, 'D1_content': 60.0, 'D2_content': 0.0, 'D6_content': 0.0, 'D8_content': 75.0} using model BoTorch.
# [INFO 09-09 15:30:18] ax.service.ax_client: Completed trial 23 with data: {'Conductivity': (686.737194, None)}.
# [INFO 09-09 15:30:21] ax.service.ax_client: Generated new trial 24 with parameters {'P3HT_content': 15.0, 'D1_content': 60.0, 'D2_content': 0.0, 'D6_content': 85.0, 'D8_content': 75.0} using model BoTorch.
# [INFO 09-09 15:30:21] ax.service.ax_client: Completed trial 24 with data: {'Conductivity': (566.470516, None)}.
# [INFO 09-09 15:30:24] ax.service.ax_client: Generated new trial 25 with parameters {'P3HT_content': 15.0, 'D1_content': 60.0, 'D2_content': 0.0, 'D6_content': 0.0, 'D8_content': 35.065032} using model BoTorch.
# [INFO 09-09 15:30:24] ax.service.ax_client: Completed trial 25 with data: {'Conductivity': (686.737194, None)}.

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor

df = pd.read_csv("Aldol Condensation.csv").dropna()
cols = ["moleq2","moleq3","temp","time","yld"]

def smooth_xy(x, y, k=11):
    # KNN smoother for a quick monotonicity glance
    x = x.reshape(-1,1)
    knn = KNeighborsRegressor(n_neighbors=min(k, len(x)))
    knn.fit(x, y)
    xs = np.linspace(x.min(), x.max(), 120).reshape(-1,1)
    ys = knn.predict(xs)
    return xs.ravel(), ys

fig, axes = plt.subplots(2,2, figsize=(10,7))
pairs = [("temp","yld"),("time","yld"),("moleq2","yld"),("moleq3","yld")]
for ax,(v, y) in zip(axes.ravel(), pairs):
    x = df[v].values; t = df[y].values
    xs, ys = smooth_xy(x, t, k=15)
    ax.scatter(x, t, s=10, alpha=0.35)
    ax.plot(xs, ys, lw=2)
    ax.set_title(f"{v} → {y}")
plt.tight_layout()
